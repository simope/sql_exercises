# %%
import sqlite3
import csv

with sqlite3.connect('olympics.db') as conn:
    cursor = conn.cursor()

    # Fresh start every time, comment out if first time creating the database
    query = "DROP TABLE athlete_events"
    cursor.execute(query)
    query = "DROP TABLE noc_regions"
    cursor.execute(query)

    # Create the table athlete_event
    query = '''
                CREATE TABLE IF NOT EXISTS athlete_events(
                ID INT,
                Name CHAR(20),
                Sex CHAR(1),
                Age INT,
                Height INT,
                Weight INT,
                Team CHAR(50),
                NOC CHAR(50),
                Games CHAR(50),
                Year INT,
                Season CHAR(50),
                City CHAR(50),
                Sport CHAR(50),
                Event CHAR(50),
                Medal CHAR(50)
            )'''
    cursor.execute(query)

    print("Table athlete_event created successfully.")

    # Create the table noc_regions
    query = '''
                CREATE TABLE IF NOT EXISTS noc_regions(
                NOC CHAR(3),
                region CHAR(30),
                notes CHAR(100)
            )'''
    cursor.execute(query)

    print("Table noc_regions created successfully.")

    with open('athlete_events.csv') as file:
        rows = csv.reader(file, delimiter=',')
        next(rows) # To skip the header
        for row in rows:
            
            query = '''
                    INSERT INTO athlete_events
                    (ID, Name, Sex, Age, Height, Weight, Team, NOC, Games, Year, Season, City, Sport, Event, Medal)
                    VALUES
                    (
                        ?,
                        ?,
                        ?,
                        ?,
                        ?,
                        ?,
                        ?,
                        ?,
                        ?,
                        ?,
                        ?,
                        ?,
                        ?,
                        ?,
                        ?
                    )
                    '''
            values = [entry for entry in row]
            cursor.execute(query, values)
    
    print("Values for athlete_events inserted successfully.")
    

    with open('noc_regions.csv') as file:
        rows = csv.reader(file, delimiter=',')
        next(rows) # To skip the header
        for row in rows:
            
            query = '''
                    INSERT INTO noc_regions
                    (NOC, region, notes)
                    VALUES
                    (
                        ?,
                        ?,
                        ?
                    )
                    '''
            values = [entry for entry in row]
            cursor.execute(query, values)
    
    print("Values for noc_regions inserted successfully.")

    conn.commit()
# Out:
# Table athlete_event created successfully.
# Table noc_regions created successfully.
# Values for athlete_events inserted successfully.
# Values for noc_regions inserted successfully.

# %%
# 1. How many olympics games have been held?

with sqlite3.connect('olympics.db') as conn:
    cursor = conn.cursor()
    query = '''
            SELECT COUNT(DISTINCT Games) FROM athlete_events
            '''

    cursor.execute(query)
    for entry in cursor.fetchall():
        print(entry)
# Out:
# (51,)

# %%
# 2. List down all Olympics games held so far.
with sqlite3.connect('olympics.db') as conn:
    cursor = conn.cursor()
    query = '''
            SELECT DISTINCT Games FROM athlete_events
            '''

    cursor.execute(query)
    for entry in cursor.fetchall():
        print(entry)
# Out:
# ('1992 Summer',)
# ('2012 Summer',)
# ('1920 Summer',)
# ('1900 Summer',)
# ('1988 Winter',)
# ('1992 Winter',)
# ('1994 Winter',)
# ('1932 Summer',)
# ('2002 Winter',)
# ('1952 Summer',)
# ('1980 Winter',)
# ('2000 Summer',)
# ('1996 Summer',)
# ('1912 Summer',)
# ('1924 Summer',)
# ('2014 Winter',)
# ('1948 Summer',)
# ('1998 Winter',)
# ('2006 Winter',)
# ('2008 Summer',)
# ('2016 Summer',)
# ('2004 Summer',)
# ('1960 Winter',)
# ('1964 Winter',)
# ('1984 Winter',)
# ('1984 Summer',)
# ('1968 Summer',)
# ('1972 Summer',)
# ('1988 Summer',)
# ('1936 Summer',)
# ('1952 Winter',)
# ('1956 Winter',)
# ('1956 Summer',)
# ('1960 Summer',)
# ('1928 Summer',)
# ('1976 Summer',)
# ('1980 Summer',)
# ('1964 Summer',)
# ('2010 Winter',)
# ('1968 Winter',)
# ('1906 Summer',)
# ('1972 Winter',)
# ('1976 Winter',)
# ('1924 Winter',)
# ('1904 Summer',)
# ('1928 Winter',)
# ('1908 Summer',)
# ('1948 Winter',)
# ('1932 Winter',)
# ('1936 Winter',)
# ('1896 Summer',)

# %%
# 3. Mention the total no of nations who participated in each olympics game?
with sqlite3.connect('olympics.db') as conn:
    cursor = conn.cursor()
    query = '''
            SELECT COUNT(DISTINCT NOC), Games FROM athlete_events
            GROUP BY Games
            '''

    cursor.execute(query)
    for entry in cursor.fetchall():
        print(entry)

# NOTE: At first I used Team, but actually different teams for the same nation appear in the historic DB.
# Using NOC it's more correct as it represents the country of origin
# Out:
# (12, '1896 Summer')
# (31, '1900 Summer')
# (15, '1904 Summer')
# (21, '1906 Summer')
# (22, '1908 Summer')
# (29, '1912 Summer')
# (29, '1920 Summer')
# (45, '1924 Summer')
# (19, '1924 Winter')
# (46, '1928 Summer')
# (25, '1928 Winter')
# (47, '1932 Summer')
# (17, '1932 Winter')
# (49, '1936 Summer')
# (28, '1936 Winter')
# (59, '1948 Summer')
# (28, '1948 Winter')
# (69, '1952 Summer')
# (30, '1952 Winter')
# (72, '1956 Summer')
# (32, '1956 Winter')
# (84, '1960 Summer')
# (30, '1960 Winter')
# (93, '1964 Summer')
# (36, '1964 Winter')
# (112, '1968 Summer')
# (37, '1968 Winter')
# (121, '1972 Summer')
# (35, '1972 Winter')
# (92, '1976 Summer')
# (37, '1976 Winter')
# (80, '1980 Summer')
# (37, '1980 Winter')
# (140, '1984 Summer')
# (49, '1984 Winter')
# (159, '1988 Summer')
# (57, '1988 Winter')
# (169, '1992 Summer')
# (64, '1992 Winter')
# (67, '1994 Winter')
# (197, '1996 Summer')
# (72, '1998 Winter')
# (200, '2000 Summer')
# (77, '2002 Winter')
# (201, '2004 Summer')
# (79, '2006 Winter')
# (204, '2008 Summer')
# (82, '2010 Winter')
# (205, '2012 Summer')
# (89, '2014 Winter')
# (207, '2016 Summer')

# %%
# 4. Which year saw the highest and lowest no of countries participating in olympics?
with sqlite3.connect('olympics.db') as conn:
    cursor = conn.cursor()
    query = '''
            SELECT Year, MAX(NumberCountries) FROM
            (SELECT Year, COUNT(DISTINCT NOC) as NumberCountries FROM athlete_events
            GROUP BY Year)
            '''

    cursor.execute(query)
    for entry in cursor.fetchall():
        print(entry)

    query = '''
            SELECT Year, MIN(NumberCountries) FROM
            (SELECT Year, COUNT(DISTINCT NOC) as NumberCountries FROM athlete_events
            GROUP BY Year)
            '''

    cursor.execute(query)
    for entry in cursor.fetchall():
        print(entry)
# Out:
# (2016, 207)
# (1896, 12)

# %%
# 5. Which nation has participated in all of the olympic games?
with sqlite3.connect('olympics.db') as conn:
    cursor = conn.cursor()
    query = '''
                    SELECT n.region, COUNT(DISTINCT a.Games) AS game_count
                    FROM athlete_events AS a JOIN noc_regions as n
                    ON a.NOC = n.NOC
                    GROUP BY n.region
                    HAVING game_count = (
                                       SELECT COUNT(DISTINCT a.Games)
                                       FROM athlete_events AS a
                            )
                    
            '''

    cursor.execute(query)
    for entry in cursor.fetchall():
        print(entry)
# Out:
# ('France', 51)
# ('Italy', 51)
# ('Switzerland', 51)
# ('UK', 51)

# %%
# 6. Identify the sport which was played in all summer olympics.
with sqlite3.connect('olympics.db') as conn:
    cursor = conn.cursor()
    query = '''
                SELECT Sport, COUNT(DISTINCT Games) as game_count
                FROM athlete_events
                GROUP BY Sport
                HAVING Season = "Summer" AND game_count = (
                                        
                                    SELECT COUNT(DISTINCT Games)
                                    FROM athlete_events
                                    WHERE Season = "Summer"
                )
            '''

    cursor.execute(query)
    for entry in cursor.fetchall():
        print(entry)
# Out:
# ('Athletics', 29)
# ('Cycling', 29)
# ('Fencing', 29)
# ('Gymnastics', 29)
# ('Swimming', 29)

# %%
# 7. Which Sports were just played only once in the olympics?
with sqlite3.connect('olympics.db') as conn:
    cursor = conn.cursor()
    query = '''
                SELECT Sport, COUNT(DISTINCT Games) as game_count
                FROM athlete_events
                GROUP BY Sport
                HAVING game_count = 1
            '''

    cursor.execute(query)
    for entry in cursor.fetchall():
        print(entry)
# Out:
# ('Aeronautics', 1)
# ('Basque Pelota', 1)
# ('Cricket', 1)
# ('Croquet', 1)
# ('Jeu De Paume', 1)
# ('Military Ski Patrol', 1)
# ('Motorboating', 1)
# ('Racquets', 1)
# ('Roque', 1)
# ('Rugby Sevens', 1)

# %%
# 9. Fetch the total no of sports played in each olympic games.
with sqlite3.connect('olympics.db') as conn:
    cursor = conn.cursor()
    query = '''
                SELECT COUNT(DISTINCT Sport) as sports_count, Games
                FROM athlete_events
                GROUP BY Games
                ORDER BY sports_count DESC
            '''

    cursor.execute(query)
    for entry in cursor.fetchall():
        print(entry)
# Out:
# (34, '2016 Summer')
# (34, '2008 Summer')
# (34, '2004 Summer')
# (34, '2000 Summer')
# (32, '2012 Summer')
# (31, '1996 Summer')
# (29, '1992 Summer')
# (27, '1988 Summer')
# (25, '1984 Summer')
# (25, '1920 Summer')
# (24, '1936 Summer')
# (24, '1908 Summer')
# (23, '1980 Summer')
# (23, '1976 Summer')
# (23, '1972 Summer')
# (21, '1964 Summer')
# (20, '1968 Summer')
# (20, '1948 Summer')
# (20, '1924 Summer')
# (20, '1900 Summer')
# (19, '1960 Summer')
# (19, '1956 Summer')
# (19, '1952 Summer')
# (18, '1932 Summer')
# (18, '1904 Summer')
# (17, '1928 Summer')
# (17, '1912 Summer')
# (15, '2014 Winter')
# (15, '2010 Winter')
# (15, '2006 Winter')
# (15, '2002 Winter')
# (14, '1998 Winter')
# (13, '1906 Summer')
# (12, '1994 Winter')
# (12, '1992 Winter')
# (10, '1988 Winter')
# (10, '1984 Winter')
# (10, '1980 Winter')
# (10, '1976 Winter')
# (10, '1972 Winter')
# (10, '1968 Winter')
# (10, '1964 Winter')
# (10, '1924 Winter')
# (9, '1948 Winter')
# (9, '1896 Summer')
# (8, '1960 Winter')
# (8, '1956 Winter')
# (8, '1952 Winter')
# (8, '1936 Winter')
# (8, '1928 Winter')
# (7, '1932 Winter')

# %%
# 10. Fetch details of the oldest athletes to win a gold medal.
with sqlite3.connect('olympics.db') as conn:
    cursor = conn.cursor()
    query = '''
                SELECT *
                FROM (
                    SELECT * 
                    FROM athlete_events
                    WHERE Medal = "Gold"
                    )
                WHERE Age = (
                    SELECT MAX(Age)
                    FROM athlete_events
                    WHERE Medal = "Gold" AND Age != "NA"
                )
                

            '''

    cursor.execute(query)
    for entry in cursor.fetchall():
        print(entry)
# Out:
# (53238, 'Charles Jacobus', 'M', 64, 'NA', 'NA', 'United States', 'USA', '1904 Summer', 1904, 'Summer', 'St. Louis', 'Roque', "Roque Men's Singles", 'Gold')
# (117046, 'Oscar Gomer Swahn', 'M', 64, 'NA', 'NA', 'Sweden', 'SWE', '1912 Summer', 1912, 'Summer', 'Stockholm', 'Shooting', "Shooting Men's Running Target, Single Shot, Team", 'Gold')

# %%
# 11. Find the Ratio of male and female athletes participated in all olympic games.
with sqlite3.connect('olympics.db') as conn:
    cursor = conn.cursor()
    query = '''
                WITH maletable (males) AS (
                    SELECT COUNT(*)
                    FROM athlete_events
                    WHERE Sex = "M"
                ),
                femaletable (females) AS (
                    SELECT COUNT(*)
                    FROM athlete_events
                    WHERE Sex = "F"            
                )
                SELECT ROUND(CAST(males AS DECIMAL), 2) / females
                FROM maletable, femaletable
            '''

    cursor.execute(query)
    for entry in cursor.fetchall():
        print(entry)
# Out:
# (2.638066611202061,)

# %%
# 12. Fetch the top 5 athletes who have won the most gold medals.
with sqlite3.connect('olympics.db') as conn:
    cursor = conn.cursor()
    query = '''
                WITH T1 AS (
                    SELECT ID, Name, Games, COUNT(Medal) AS Golds_Number
                    FROM (
                        SELECT *
                        FROM athlete_events
                        WHERE Medal = "Gold"
                    )
                    GROUP BY ID
                ),
                T2 as
                    (SELECT *, DENSE_RANK() OVER (ORDER BY Golds_Number desc) as rank
                    FROM T1)
                
                SELECT * 
                FROM T2
                WHERE rank <= 5
            '''

    cursor.execute(query)
    for entry in cursor.fetchall():
        print(entry)
# Out:
# (94406, 'Michael Fred Phelps, II', '2004 Summer', 23, 1)
# (33557, 'Raymond Clarence "Ray" Ewry', '1900 Summer', 10, 2)
# (67046, 'Larysa Semenivna Latynina (Diriy-)', '1956 Summer', 9, 3)
# (69210, 'Frederick Carlton "Carl" Lewis', '1984 Summer', 9, 3)
# (87390, 'Paavo Johannes Nurmi', '1920 Summer', 9, 3)
# (113912, 'Mark Andrew Spitz', '1968 Summer', 9, 3)
# (11642, 'Matthew Nicholas "Matt" Biondi', '1984 Summer', 8, 4)
# (11951, 'Ole Einar Bjrndalen', '1998 Winter', 8, 4)
# (13029, 'Usain St. Leo Bolt', '2008 Summer', 8, 4)
# (35550, 'Birgit Fischer-Schmidt', '1980 Summer', 8, 4)
# (57998, 'Sawao Kato', '1968 Summer', 8, 4)
# (119922, 'Jennifer Elisabeth "Jenny" Thompson (-Cumpelik)', '1992 Summer', 8, 4)
# (4198, 'Nikolay Yefimovich Andrianov', '1972 Summer', 7, 5)
# (18826, 'Vra slavsk (-Odloilov)', '1964 Summer', 7, 5)
# (21402, 'Viktor Ivanovych Chukarin', '1952 Summer', 7, 5)
# (39726, 'Aladr Gerevich (-Gerei)', '1932 Summer', 7, 5)
# (107383, 'Donald Arthur "Don" Schollander', '1964 Summer', 7, 5)
# (109161, 'Borys Anfiyanovych Shakhlin', '1956 Summer', 7, 5)

# %%
# 13. Fetch the top 5 athletes who have won the most medals (gold/silver/bronze).
with sqlite3.connect('olympics.db') as conn:
    cursor = conn.cursor()
    query = '''
                WITH T1 AS (
                    SELECT ID, Name, COUNT(Medal) AS Medal_Number
                    FROM (
                        SELECT *
                        FROM athlete_events
                        WHERE Medal != "NA"
                    )
                    GROUP BY ID

                ),
                T2 as
                    (SELECT *, DENSE_RANK() OVER (ORDER BY Medal_Number DESC) as rank
                    FROM T1)
                
                SELECT * 
                FROM T2
                WHERE rank <= 5
            '''

    cursor.execute(query)
    for entry in cursor.fetchall():
        print(entry)
# Out:
# (94406, 'Michael Fred Phelps, II', 28, 1)
# (67046, 'Larysa Semenivna Latynina (Diriy-)', 18, 2)
# (4198, 'Nikolay Yefimovich Andrianov', 15, 3)
# (11951, 'Ole Einar Bjrndalen', 13, 4)
# (74420, 'Edoardo Mangiarotti', 13, 4)
# (89187, 'Takashi Ono', 13, 4)
# (109161, 'Borys Anfiyanovych Shakhlin', 13, 4)
# (23426, 'Natalie Anne Coughlin (-Hall)', 12, 5)
# (35550, 'Birgit Fischer-Schmidt', 12, 5)
# (57998, 'Sawao Kato', 12, 5)
# (70965, 'Ryan Steven Lochte', 12, 5)
# (85286, 'Aleksey Yuryevich Nemov', 12, 5)
# (87390, 'Paavo Johannes Nurmi', 12, 5)
# (119922, 'Jennifer Elisabeth "Jenny" Thompson (-Cumpelik)', 12, 5)
# (121258, 'Dara Grace Torres (-Hoffman, -Minas)', 12, 5)

# %%
# 14. Fetch the top 5 most successful countries in olympics. Success is defined by no of medals won.
with sqlite3.connect('olympics.db') as conn:
    cursor = conn.cursor()
    query = '''
                WITH T1 AS (
                    SELECT n.region, COUNT(1) AS Medals_count
                    FROM athlete_events as a
                    JOIN noc_regions as n on a.NOC = n.NOC
                    WHERE a.Medal != "NA"
                    GROUP BY region
                ),
                
                T2 as
                    (SELECT *, DENSE_RANK() OVER (ORDER BY Medals_count DESC) as rank
                    FROM T1)
                
                SELECT * 
                FROM T2
                WHERE rank <= 5
            '''

    cursor.execute(query)
    for entry in cursor.fetchall():
        print(entry)
# Out:
# ('USA', 5637, 1)
# ('Russia', 3947, 2)
# ('Germany', 3756, 3)
# ('UK', 2068, 4)
# ('France', 1777, 5)

# %%
# 15. List down total gold, silver and broze medals won by each country.
with sqlite3.connect('olympics.db') as conn:
    cursor = conn.cursor()
    query = ''' 
                WITH T1 AS (
                SELECT region,
                CASE Medal
                    WHEN 'Gold' THEN 1
                END AS Gold,
                CASE Medal
                    WHEN 'Silver' THEN 1
                END AS Silver,
                CASE Medal
                    WHEN 'Bronze' THEN 1
                END AS Bronze
                FROM athlete_events
                JOIN noc_regions on noc_regions.NOC = athlete_events.NOC
                )

                SELECT region, SUM(Gold) as Gold_num, SUM(Silver), SUM(Bronze)
                FROM T1
                GROUP BY region
                ORDER BY Gold_num DESC
            '''

    cursor.execute(query)
    for entry in cursor.fetchall():
        print(entry)
# Out:
# ('USA', 2638, 1641, 1358)
# ('Russia', 1599, 1170, 1178)
# ('Germany', 1301, 1195, 1260)
# ('UK', 678, 739, 651)
# ('Italy', 575, 531, 531)
# ('France', 501, 610, 666)
# ('Sweden', 479, 522, 535)
# ('Canada', 463, 438, 451)
# ('Hungary', 432, 332, 371)
# ('Norway', 378, 361, 294)
# ('Australia', 368, 459, 522)
# ('China', 351, 349, 293)
# ('Netherlands', 287, 340, 413)
# ('Japan', 247, 309, 357)
# ('South Korea', 221, 232, 185)
# ('Finland', 198, 270, 432)
# ('Denmark', 179, 241, 177)
# ('Switzerland', 175, 248, 268)
# ('Cuba', 164, 129, 116)
# ('Romania', 161, 200, 292)
# ('Serbia', 157, 222, 160)
# ('India', 138, 19, 40)
# ('Czech Republic', 123, 262, 259)
# ('Poland', 117, 195, 253)
# ('Spain', 110, 243, 136)
# ('Brazil', 109, 175, 191)
# ('Austria', 108, 186, 156)
# ('Belgium', 98, 197, 173)
# ('Argentina', 91, 92, 91)
# ('New Zealand', 90, 56, 82)
# ('Greece', 62, 109, 84)
# ('Croatia', 58, 54, 37)
# ('Bulgaria', 54, 144, 144)
# ('Ukraine', 47, 52, 100)
# ('Pakistan', 42, 45, 34)
# ('Turkey', 40, 27, 28)
# ('Jamaica', 38, 75, 44)
# ('Kenya', 34, 41, 31)
# ('South Africa', 32, 47, 52)
# ('Uruguay', 31, 2, 30)
# ('Mexico', 30, 26, 54)
# ('Belarus', 24, 44, 71)
# ('Nigeria', 23, 30, 46)
# ('Ethiopia', 22, 9, 22)
# ('Kazakhstan', 20, 25, 32)
# ('Cameroon', 20, 1, 1)
# ('Iran', 18, 21, 29)
# ('Zimbabwe', 17, 4, 1)
# ('North Korea', 16, 16, 35)
# ('Slovakia', 15, 19, 13)
# ('Bahamas', 14, 11, 15)
# ('Fiji', 13, None, None)
# ('Estonia', 13, 12, 25)
# ('Indonesia', 11, 17, 13)
# ('Uzbekistan', 10, 7, 17)
# ('Thailand', 9, 8, 13)
# ('Ireland', 9, 13, 13)
# ('Slovenia', 8, 13, 27)
# ('Georgia', 8, 6, 18)
# ('Trinidad', 7, 8, 22)
# ('Egypt', 7, 8, 12)
# ('Azerbaijan', 7, 12, 25)
# ('Morocco', 6, 5, 12)
# ('Lithuania', 6, 7, 48)
# ('Colombia', 5, 9, 14)
# ('Algeria', 5, 4, 8)
# ('Portugal', 4, 11, 26)
# ('Luxembourg', 4, 4, None)
# ('Tunisia', 3, 3, 7)
# ('Taiwan', 3, 28, 18)
# ('Latvia', 3, 19, 13)
# ('Dominican Republic', 3, 2, 2)
# ('Chile', 3, 9, 20)
# ('Venezuela', 2, 3, 10)
# ('Uganda', 2, 3, 2)
# ('Mongolia', 2, 10, 14)
# ('Liechtenstein', 2, 2, 5)
# ('Armenia', 2, 5, 9)
# ('Vietnam', 1, 3, None)
# ('United Arab Emirates', 1, None, 1)
# ('Tajikistan', 1, 1, 2)
# ('Syria', 1, 2, 2)
# ('Suriname', 1, None, 1)
# ('Puerto Rico', 1, 2, 6)
# ('Peru', 1, 14, None)
# ('Panama', 1, None, 2)
# ('Nepal', 1, None, None)
# ('Mozambique', 1, None, 1)
# ('Kosovo', 1, None, None)
# ('Jordan', 1, None, None)
# ('Ivory Coast', 1, 1, 1)
# ('Israel', 1, 1, 7)
# ('Individual Olympic Athletes', 1, 1, 3)
# ('Haiti', 1, 1, 5)
# ('Grenada', 1, 1, None)
# ('Ecuador', 1, 1, None)
# ('Costa Rica', 1, 1, 2)
# ('Burundi', 1, 1, None)
# ('Bahrain', 1, 1, 1)
# ('Zambia', None, 1, 1)
# ('Yemen', None, None, None)
# ('Virgin Islands, US', None, 1, None)
# ('Virgin Islands, British', None, None, None)
# ('Vanuatu', None, None, None)
# ('Turkmenistan', None, None, None)
# ('Tonga', None, 1, None)
# ('Togo', None, None, 1)
# ('Timor-Leste', None, None, None)
# ('Tanzania', None, 2, None)
# ('Swaziland', None, None, None)
# ('Sudan', None, 1, None)
# ('Sri Lanka', None, 2, None)
# ('South Sudan', None, None, None)
# ('Somalia', None, None, None)
# ('Solomon Islands', None, None, None)
# ('Sierra Leone', None, None, None)
# ('Seychelles', None, None, None)
# ('Senegal', None, 1, None)
# ('Saudi Arabia', None, 1, 5)
# ('Sao Tome and Principe', None, None, None)
# ('San Marino', None, None, None)
# ('Samoa', None, None, None)
# ('Saint Vincent', None, None, None)
# ('Saint Lucia', None, None, None)
# ('Saint Kitts', None, None, None)
# ('Rwanda', None, None, None)
# ('Republic of Congo', None, None, None)
# ('Qatar', None, 1, 4)
# ('Philippines', None, 3, 7)
# ('Paraguay', None, 17, None)
# ('Papua New Guinea', None, None, None)
# ('Palestine', None, None, None)
# ('Palau', None, None, None)
# ('Oman', None, None, None)
# ('Niger', None, 1, 1)
# ('Nicaragua', None, None, None)
# ('Nauru', None, None, None)
# ('Namibia', None, 4, None)
# ('NA', None, None, None)
# ('Myanmar', None, None, None)
# ('Montenegro', None, 14, None)
# ('Monaco', None, None, 1)
# ('Moldova', None, 3, 5)
# ('Micronesia', None, None, None)
# ('Mauritius', None, None, 1)
# ('Mauritania', None, None, None)
# ('Marshall Islands', None, None, None)
# ('Malta', None, None, None)
# ('Mali', None, None, None)
# ('Maldives', None, None, None)
# ('Malaysia', None, 11, 5)
# ('Malawi', None, None, None)
# ('Madagascar', None, None, None)
# ('Macedonia', None, None, 1)
# ('Libya', None, None, None)
# ('Liberia', None, None, None)
# ('Lesotho', None, None, None)
# ('Lebanon', None, 2, 2)
# ('Laos', None, None, None)
# ('Kyrgyzstan', None, 1, 2)
# ('Kuwait', None, None, 2)
# ('Kiribati', None, None, None)
# ('Iraq', None, None, 1)
# ('Iceland', None, 15, 2)
# ('Honduras', None, None, None)
# ('Guyana', None, None, 1)
# ('Guinea-Bissau', None, None, None)
# ('Guinea', None, None, None)
# ('Guatemala', None, 1, None)
# ('Guam', None, None, None)
# ('Ghana', None, 1, 22)
# ('Gambia', None, None, None)
# ('Gabon', None, 1, None)
# ('Eritrea', None, None, 1)
# ('Equatorial Guinea', None, None, None)
# ('El Salvador', None, None, None)
# ('Dominica', None, None, None)
# ('Djibouti', None, None, 1)
# ('Democratic Republic of the Congo', None, None, None)
# ('Cyprus', None, 1, None)
# ('Curacao', None, 1, None)
# ('Cook Islands', None, None, None)
# ('Comoros', None, None, None)
# ('Chad', None, None, None)
# ('Central African Republic', None, None, None)
# ('Cayman Islands', None, None, None)
# ('Cape Verde', None, None, None)
# ('Cambodia', None, None, None)
# ('Burkina Faso', None, None, None)
# ('Brunei', None, None, None)
# ('Botswana', None, 1, None)
# ('Bosnia and Herzegovina', None, None, None)
# ('Boliva', None, None, None)
# ('Bhutan', None, None, None)
# ('Bermuda', None, None, 1)
# ('Benin', None, None, None)
# ('Belize', None, None, None)
# ('Barbados', None, None, 1)
# ('Bangladesh', None, None, None)
# ('Aruba', None, None, None)
# ('Antigua', None, None, None)
# ('Angola', None, None, None)
# ('Andorra', None, None, None)
# ('American Samoa', None, None, None)
# ('Albania', None, None, None)
# ('Afghanistan', None, None, 2)

# %%
# 16. List down total gold, silver and broze medals won by each country corresponding to each olympic games.
with sqlite3.connect('olympics.db') as conn:
    cursor = conn.cursor()
    query = ''' 
                WITH T1 AS (
                SELECT region, Games,
                CASE Medal
                    WHEN 'Gold' THEN 1
                END AS Gold,
                CASE Medal
                    WHEN 'Silver' THEN 1
                END AS Silver,
                CASE Medal
                    WHEN 'Bronze' THEN 1
                END AS Bronze
                FROM athlete_events
                JOIN noc_regions on noc_regions.NOC = athlete_events.NOC
                )

                SELECT Games, region, SUM(Gold) as Gold_num, SUM(Silver), SUM(Bronze)
                FROM T1
                GROUP BY Games, region
                ORDER BY Gold_num DESC
            '''

    cursor.execute(query)
    for entry in cursor.fetchall():
        print(entry)
# Out:
# ('1980 Summer', 'Russia', 187, 129, 126)
# ('1984 Summer', 'USA', 186, 116, 50)
# ('1996 Summer', 'USA', 159, 48, 52)
# ('1908 Summer', 'UK', 147, 131, 90)
# ('2012 Summer', 'USA', 145, 57, 46)
# ('2016 Summer', 'USA', 139, 54, 71)
# ('1988 Summer', 'Russia', 134, 67, 99)
# ('2000 Summer', 'USA', 130, 61, 51)
# ('1904 Summer', 'USA', 128, 141, 125)
# ('2008 Summer', 'USA', 127, 110, 80)
# ('1976 Summer', 'Germany', 123, 76, 74)
# ('2004 Summer', 'USA', 117, 75, 71)
# ('1980 Summer', 'Germany', 115, 88, 61)
# ('1976 Summer', 'Russia', 114, 95, 77)
# ('1920 Summer', 'USA', 111, 45, 38)
# ('1988 Summer', 'Germany', 111, 91, 94)
# ('1972 Summer', 'Russia', 107, 47, 60)
# ('1912 Summer', 'Sweden', 103, 62, 25)
# ('1968 Summer', 'USA', 99, 32, 35)
# ('1924 Summer', 'USA', 97, 36, 49)
# ('1964 Summer', 'USA', 95, 37, 37)
# ('1936 Summer', 'Germany', 93, 70, 61)
# ('1992 Summer', 'Russia', 92, 61, 67)
# ('1992 Summer', 'USA', 89, 50, 85)
# ('1948 Summer', 'USA', 87, 30, 35)
# ('1988 Summer', 'USA', 87, 66, 54)
# ('1952 Summer', 'USA', 83, 23, 28)
# ('1932 Summer', 'USA', 81, 47, 61)
# ('1960 Summer', 'USA', 81, 23, 21)
# ('1992 Summer', 'Germany', 81, 57, 60)
# ('1972 Summer', 'Germany', 74, 83, 96)
# ('2008 Summer', 'China', 74, 53, 57)
# ('1976 Summer', 'USA', 70, 58, 36)
# ('1972 Summer', 'USA', 69, 59, 43)
# ('1956 Summer', 'Russia', 68, 46, 55)
# ('1920 Summer', 'Italy', 67, 9, 8)
# ('2010 Winter', 'Canada', 67, 15, 8)
# ('2000 Summer', 'Russia', 66, 67, 54)
# ('1968 Summer', 'Russia', 65, 63, 64)
# ('2016 Summer', 'UK', 64, 55, 26)
# ('1956 Summer', 'USA', 61, 42, 20)
# ('1960 Summer', 'Russia', 61, 63, 45)
# ('1964 Summer', 'Russia', 60, 63, 51)
# ('2000 Summer', 'Australia', 60, 69, 54)
# ('1900 Summer', 'UK', 59, 34, 15)
# ('2014 Winter', 'Canada', 59, 22, 5)
# ('1920 Summer', 'Norway', 58, 52, 27)
# ('1920 Summer', 'Belgium', 57, 65, 66)
# ('2012 Summer', 'China', 56, 40, 30)
# ('1952 Summer', 'Hungary', 53, 17, 32)
# ('1900 Summer', 'France', 52, 101, 82)
# ('1920 Summer', 'Sweden', 52, 38, 64)
# ('1920 Summer', 'UK', 52, 42, 17)
# ('2002 Winter', 'Canada', 52, 7, 15)
# ('2004 Summer', 'China', 52, 29, 15)
# ('2016 Summer', 'Russia', 52, 28, 35)
# ('1936 Summer', 'USA', 51, 29, 16)
# ('2012 Summer', 'Russia', 50, 39, 51)
# ('2004 Summer', 'Australia', 49, 77, 31)
# ('2016 Summer', 'Germany', 49, 43, 67)
# ('1908 Summer', 'Sweden', 48, 18, 18)
# ('1992 Summer', 'Spain', 48, 19, 2)
# ('2004 Summer', 'Russia', 48, 46, 95)
# ('2012 Summer', 'UK', 48, 30, 48)
# ('1912 Summer', 'UK', 47, 64, 59)
# ('1928 Summer', 'USA', 47, 24, 17)
# ('1984 Summer', 'Serbia', 47, 5, 35)
# ('1912 Summer', 'USA', 46, 25, 36)
# ('2016 Summer', 'China', 46, 30, 37)
# ('2012 Summer', 'Germany', 45, 27, 22)
# ('2008 Summer', 'Russia', 43, 46, 53)
# ('1964 Summer', 'Hungary', 42, 7, 7)
# ('1992 Summer', 'Cuba', 42, 13, 14)
# ('1996 Summer', 'Germany', 42, 35, 47)
# ('2008 Summer', 'Germany', 42, 16, 41)
# ('2004 Summer', 'Germany', 41, 45, 63)
# ('2008 Summer', 'South Korea', 41, 11, 26)
# ('1912 Summer', 'Norway', 40, 6, 34)
# ('1984 Summer', 'Romania', 40, 31, 35)
# ('1988 Winter', 'Russia', 40, 14, 12)
# ('2000 Summer', 'China', 39, 23, 17)
# ('2008 Summer', 'Netherlands', 39, 18, 4)
# ('1976 Winter', 'Russia', 38, 7, 11)
# ('1996 Summer', 'Netherlands', 38, 9, 26)
# ('1924 Summer', 'France', 37, 51, 22)
# ('1936 Summer', 'Italy', 37, 34, 5)
# ('1996 Summer', 'Cuba', 37, 8, 10)
# ('1952 Summer', 'Russia', 36, 62, 19)
# ('1960 Summer', 'Italy', 36, 18, 34)
# ('1972 Winter', 'Russia', 36, 6, 3)
# ('1996 Summer', 'Russia', 36, 45, 34)
# ('2016 Summer', 'Brazil', 36, 8, 6)
# ('1992 Winter', 'Russia', 35, 10, 14)
# ('2006 Winter', 'Sweden', 35, 21, 8)
# ('1908 Summer', 'USA', 34, 16, 15)
# ('1960 Summer', 'Germany', 34, 33, 22)
# ('2014 Winter', 'Russia', 33, 22, 13)
# ('1964 Summer', 'Japan', 32, 5, 25)
# ('1968 Summer', 'Hungary', 32, 20, 29)
# ('1996 Summer', 'Australia', 32, 16, 84)
# ('2004 Summer', 'Cuba', 32, 8, 22)
# ('2000 Summer', 'Germany', 31, 23, 64)
# ('2008 Summer', 'Australia', 31, 42, 76)
# ('2008 Summer', 'UK', 31, 25, 25)
# ('1900 Summer', 'USA', 30, 16, 17)
# ('1948 Summer', 'Sweden', 30, 15, 30)
# ('1956 Summer', 'Hungary', 30, 20, 14)
# ('1964 Winter', 'Russia', 30, 8, 9)
# ('1968 Summer', 'Germany', 30, 36, 37)
# ('1984 Summer', 'Germany', 30, 75, 53)
# ('2006 Winter', 'Canada', 30, 28, 11)
# ('2012 Summer', 'France', 30, 30, 22)
# ('1972 Summer', 'Japan', 29, 19, 8)
# ('1984 Summer', 'Italy', 29, 6, 28)
# ('1984 Winter', 'Russia', 29, 15, 12)
# ('1956 Summer', 'Australia', 28, 13, 26)
# ('1988 Summer', 'South Korea', 28, 37, 12)
# ('1992 Summer', 'South Korea', 28, 5, 16)
# ('2004 Summer', 'Argentina', 28, None, 21)
# ('1904 Summer', 'Canada', 27, 9, 12)
# ('1972 Summer', 'Poland', 27, 8, 11)
# ('1992 Summer', 'Canada', 27, 5, 12)
# ('2000 Summer', 'Netherlands', 27, 29, 23)
# ('2000 Summer', 'Romania', 27, 6, 13)
# ('1920 Summer', 'Denmark', 26, 44, 1)
# ('1932 Summer', 'France', 26, 8, 6)
# ('1948 Summer', 'France', 26, 22, 24)
# ('1956 Summer', 'Italy', 26, 11, 10)
# ('1956 Winter', 'Russia', 26, 5, 6)
# ('1968 Winter', 'Russia', 26, 6, 5)
# ('2002 Winter', 'Germany', 26, 23, 12)
# ('1896 Summer', 'Germany', 25, 5, 2)
# ('1924 Summer', 'Italy', 25, 5, 21)
# ('1936 Summer', 'Hungary', 25, 1, 15)
# ('1976 Summer', 'Japan', 25, 6, 10)
# ('1998 Winter', 'USA', 25, 4, 5)
# ('2000 Summer', 'Hungary', 25, 24, 4)
# ('2008 Summer', 'France', 25, 24, 28)
# ('1906 Summer', 'Greece', 24, 48, 30)
# ('1924 Summer', 'Finland', 24, 13, 15)
# ('1928 Summer', 'Italy', 24, 22, 26)
# ('1980 Winter', 'USA', 24, 4, 2)
# ('1984 Summer', 'China', 24, 13, 37)
# ('2004 Summer', 'Hungary', 24, 12, 4)
# ('2004 Summer', 'Italy', 24, 41, 39)
# ('1952 Summer', 'Sweden', 23, 24, 23)
# ('1994 Winter', 'Sweden', 23, 1, None)
# ('1996 Summer', 'Spain', 23, 21, 22)
# ('2002 Winter', 'Norway', 23, 11, 7)
# ('2004 Summer', 'Romania', 23, 5, 11)
# ('2006 Winter', 'Germany', 23, 25, 6)
# ('2008 Summer', 'Japan', 23, 15, 13)
# ('2016 Summer', 'Australia', 23, 34, 25)
# ('1912 Summer', 'Italy', 22, 1, 2)
# ('1964 Summer', 'Germany', 22, 44, 50)
# ('1988 Summer', 'UK', 22, 17, 15)
# ('1998 Winter', 'Germany', 22, 12, 10)
# ('2000 Summer', 'France', 22, 30, 14)
# ('2000 Summer', 'Italy', 22, 14, 29)
# ('2000 Summer', 'UK', 22, 20, 12)
# ('1906 Summer', 'Italy', 21, 8, 27)
# ('1920 Summer', 'Finland', 21, 14, 17)
# ('1928 Summer', 'Germany', 21, 15, 41)
# ('1932 Summer', 'Italy', 21, 38, 18)
# ('1948 Summer', 'Italy', 21, 32, 14)
# ('1992 Summer', 'Italy', 21, 10, 14)
# ('1996 Summer', 'Denmark', 21, 1, 1)
# ('1996 Summer', 'France', 21, 10, 20)
# ('1998 Winter', 'Czech Republic', 21, 1, 1)
# ('2004 Summer', 'France', 21, 10, 22)
# ('2004 Summer', 'Japan', 21, 20, 52)
# ('2012 Summer', 'Netherlands', 21, 29, 19)
# ('2016 Summer', 'Argentina', 21, 1, None)
# ('1906 Summer', 'France', 20, 16, 28)
# ('1906 Summer', 'Norway', 20, 5, None)
# ('1928 Summer', 'Netherlands', 20, 29, 8)
# ('1932 Summer', 'Hungary', 20, 5, 8)
# ('1948 Summer', 'India', 20, None, None)
# ('1984 Summer', 'France', 20, 16, 31)
# ('1984 Summer', 'Netherlands', 20, 7, 14)
# ('1988 Summer', 'Hungary', 20, 9, 15)
# ('1996 Summer', 'China', 20, 70, 17)
# ('2000 Summer', 'Norway', 20, 4, 19)
# ('2008 Summer', 'Argentina', 20, None, 31)
# ('2016 Summer', 'France', 20, 55, 21)
# ('1936 Summer', 'India', 19, None, None)
# ('1960 Winter', 'USA', 19, 4, 4)
# ('1984 Summer', 'Canada', 19, 36, 32)
# ('1994 Winter', 'Russia', 19, 13, 4)
# ('1996 Summer', 'Italy', 19, 24, 28)
# ('2004 Summer', 'Denmark', 19, 1, 9)
# ('1976 Summer', 'Poland', 18, 29, 26)
# ('1980 Summer', 'France', 18, 5, 6)
# ('1980 Winter', 'Russia', 18, 29, 7)
# ('1988 Summer', 'Australia', 18, 6, 11)
# ('1992 Summer', 'China', 18, 45, 19)
# ('1994 Winter', 'Germany', 18, 10, 12)
# ('2000 Summer', 'Cameroon', 18, None, None)
# ('2000 Summer', 'Cuba', 18, 35, 12)
# ('2000 Summer', 'Denmark', 18, 3, 4)
# ('2004 Summer', 'Brazil', 18, 19, 3)
# ('2012 Summer', 'Australia', 18, 37, 59)
# ('2012 Summer', 'South Korea', 18, 13, 30)
# ('2014 Winter', 'Norway', 18, 5, 13)
# ('1928 Summer', 'Uruguay', 17, None, None)
# ('1948 Summer', 'Finland', 17, 8, 8)
# ('1952 Summer', 'Italy', 17, 22, 15)
# ('1956 Summer', 'India', 17, None, None)
# ('1980 Summer', 'Czech Republic', 17, 18, 16)
# ('1996 Summer', 'Nigeria', 17, 4, 3)
# ('2004 Summer', 'UK', 17, 25, 15)
# ('2016 Summer', 'Japan', 17, 13, 34)
# ('1900 Summer', 'Switzerland', 16, 4, 1)
# ('1924 Winter', 'UK', 16, 4, 11)
# ('1928 Summer', 'Switzerland', 16, 10, 4)
# ('1952 Winter', 'Canada', 16, None, 1)
# ('1960 Summer', 'Serbia', 16, 1, None)
# ('1968 Summer', 'Japan', 16, 25, 22)
# ('1980 Summer', 'India', 16, None, None)
# ('1980 Winter', 'Germany', 16, 13, 18)
# ('1984 Summer', 'New Zealand', 16, 1, 6)
# ('1984 Summer', 'Pakistan', 16, None, None)
# ('1984 Winter', 'Germany', 16, 14, 11)
# ('1996 Summer', 'Croatia', 16, 12, None)
# ('2006 Winter', 'Austria', 16, 7, 7)
# ('2006 Winter', 'Russia', 16, 12, 13)
# ('2008 Summer', 'Hungary', 16, 8, 3)
# ('2008 Summer', 'Norway', 16, 5, 1)
# ('2010 Winter', 'Norway', 16, 14, 9)
# ('2012 Summer', 'Italy', 16, 22, 30)
# ('2012 Summer', 'Mexico', 16, 5, 3)
# ('1908 Summer', 'Australia', 15, 2, 2)
# ('1920 Summer', 'Netherlands', 15, 10, 25)
# ('1924 Summer', 'UK', 15, 30, 19)
# ('1932 Summer', 'India', 15, None, None)
# ('1948 Summer', 'Hungary', 15, 25, 22)
# ('1964 Summer', 'India', 15, None, None)
# ('1972 Summer', 'Serbia', 15, 1, 2)
# ('1976 Summer', 'New Zealand', 15, 1, 9)
# ('1980 Summer', 'Zimbabwe', 15, None, None)
# ('1988 Summer', 'Serbia', 15, 27, 21)
# ('2004 Summer', 'Croatia', 15, 3, 3)
# ('2010 Winter', 'Germany', 15, 24, 15)
# ('2012 Summer', 'Croatia', 15, 4, 16)
# ('2012 Summer', 'Norway', 15, 1, 1)
# ('2014 Winter', 'Germany', 15, 12, 9)
# ('2016 Summer', 'Denmark', 15, 10, 16)
# ('1900 Summer', 'Germany', 14, 20, 11)
# ('1906 Summer', 'Denmark', 14, 19, 1)
# ('1906 Summer', 'Germany', 14, 10, 6)
# ('1908 Summer', 'Canada', 14, 8, 30)
# ('1924 Summer', 'Norway', 14, 5, 3)
# ('1924 Summer', 'Switzerland', 14, 25, 21)
# ('1924 Summer', 'Uruguay', 14, None, None)
# ('1928 Summer', 'India', 14, None, None)
# ('1932 Winter', 'Canada', 14, 1, 5)
# ('1948 Summer', 'Czech Republic', 14, 3, 3)
# ('1952 Summer', 'France', 14, 9, 17)
# ('1952 Summer', 'India', 14, None, 1)
# ('1956 Summer', 'Sweden', 14, 14, 6)
# ('1964 Summer', 'Italy', 14, 28, 9)
# ('1976 Summer', 'Hungary', 14, 6, 35)
# ('1976 Winter', 'Germany', 14, 13, 37)
# ('1988 Winter', 'Germany', 14, 22, 10)
# ('1992 Summer', 'Australia', 14, 27, 16)
# ('1992 Summer', 'Hungary', 14, 23, 8)
# ('1992 Winter', 'Germany', 14, 17, 7)
# ('1994 Winter', 'Italy', 14, 6, 12)
# ('1998 Winter', 'Canada', 14, 28, 7)
# ('1998 Winter', 'Russia', 14, 32, 6)
# ('2004 Summer', 'South Korea', 14, 28, 10)
# ('2006 Winter', 'South Korea', 14, 3, 2)
# ('2008 Summer', 'Brazil', 14, 34, 30)
# ('2012 Summer', 'Brazil', 14, 34, 11)
# ('2016 Summer', 'Serbia', 14, 27, 13)
# ('1920 Summer', 'France', 13, 71, 57)
# ('1932 Summer', 'Sweden', 13, 7, 12)
# ('1936 Summer', 'France', 13, 13, 18)
# ('1948 Winter', 'Canada', 13, None, 2)
# ('1960 Summer', 'Hungary', 13, 16, 37)
# ('1960 Summer', 'Pakistan', 13, None, 1)
# ('1968 Summer', 'Pakistan', 13, None, None)
# ('1968 Summer', 'Serbia', 13, 14, 2)
# ('1980 Summer', 'Serbia', 13, 27, 17)
# ('1992 Summer', 'Brazil', 13, 1, None)
# ('1996 Summer', 'Romania', 13, 10, 15)
# ('1998 Winter', 'Norway', 13, 15, 12)
# ('2014 Winter', 'Netherlands', 13, 7, 9)
# ('2016 Summer', 'Fiji', 13, None, None)
# ('2016 Summer', 'South Korea', 13, 3, 10)
# ('1906 Summer', 'USA', 12, 6, 6)
# ('1908 Summer', 'France', 12, 5, 23)
# ('1928 Summer', 'France', 12, 24, 14)
# ('1928 Winter', 'Canada', 12, None, None)
# ('1936 Summer', 'UK', 12, 16, 8)
# ('1936 Winter', 'UK', 12, 1, 4)
# ('1968 Summer', 'France', 12, 5, 10)
# ('1988 Summer', 'France', 12, 4, 13)
# ('2000 Summer', 'South Korea', 12, 26, 35)
# ('2010 Winter', 'USA', 12, 63, 22)
# ('2012 Summer', 'Hungary', 12, 8, 6)
# ('2016 Summer', 'Hungary', 12, 3, 7)
# ('1896 Summer', 'USA', 11, 7, 2)
# ('1912 Summer', 'Germany', 11, 19, 23)
# ('1952 Summer', 'Czech Republic', 11, 4, 10)
# ('1960 Summer', 'Australia', 11, 24, 11)
# ('1968 Winter', 'Norway', 11, 9, 2)
# ('1972 Summer', 'Australia', 11, 7, 2)
# ('1988 Summer', 'Italy', 11, 10, 8)
# ('2000 Summer', 'Serbia', 11, 1, 13)
# ('2002 Winter', 'USA', 11, 58, 15)
# ('2006 Winter', 'Italy', 11, None, 14)
# ('2008 Summer', 'Canada', 11, 13, 11)
# ('2010 Winter', 'Austria', 11, 9, 6)
# ('2010 Winter', 'Sweden', 11, 3, 4)
# ('2016 Summer', 'Jamaica', 11, 17, 2)
# ('1896 Summer', 'Greece', 10, 18, 20)
# ('1912 Summer', 'France', 10, 11, 5)
# ('1912 Summer', 'Hungary', 10, 17, 3)
# ('1920 Summer', 'Canada', 10, 3, 3)
# ('1928 Summer', 'Hungary', 10, 11, None)
# ('1932 Summer', 'Germany', 10, 26, 7)
# ('1932 Summer', 'Japan', 10, 17, 4)
# ('1932 Winter', 'USA', 10, 21, 3)
# ('1964 Summer', 'Poland', 10, 13, 23)
# ('1972 Summer', 'Hungary', 10, 46, 25)
# ('1984 Summer', 'Japan', 10, 8, 31)
# ('1988 Summer', 'Bulgaria', 10, 14, 17)
# ('1996 Summer', 'South Korea', 10, 49, 7)
# ('1996 Summer', 'Ukraine', 10, 5, 19)
# ('2008 Summer', 'Ukraine', 10, 5, 16)
# ('2014 Winter', 'USA', 10, 30, 24)
# ('1906 Summer', 'UK', 9, 22, 8)
# ('1912 Summer', 'Finland', 9, 40, 22)
# ('1924 Winter', 'Canada', 9, None, None)
# ('1932 Summer', 'UK', 9, 12, 14)
# ('1936 Summer', 'Japan', 9, 4, 10)
# ('1936 Summer', 'Netherlands', 9, 7, 21)
# ('1956 Summer', 'Germany', 9, 20, 23)
# ('1960 Summer', 'Japan', 9, 10, 12)
# ('1968 Summer', 'UK', 9, 5, 5)
# ('1972 Summer', 'Italy', 9, 3, 13)
# ('1972 Summer', 'New Zealand', 9, 4, 1)
# ('1972 Winter', 'Germany', 9, 5, 16)
# ('1976 Summer', 'Sweden', 9, 1, None)
# ('1984 Summer', 'UK', 9, 20, 42)
# ('1992 Summer', 'France', 9, 5, 43)
# ('1992 Winter', 'Austria', 9, 10, 10)
# ('1992 Winter', 'Norway', 9, 10, 5)
# ('2006 Winter', 'USA', 9, 11, 32)
# ('2010 Winter', 'China', 9, 3, 7)
# ('2012 Summer', 'New Zealand', 9, 3, 15)
# ('2012 Summer', 'Ukraine', 9, 5, 12)
# ('2016 Summer', 'Netherlands', 9, 25, 13)
# ('2016 Summer', 'Spain', 9, 19, 17)
# ('1906 Summer', 'Switzerland', 8, 3, 1)
# ('1924 Summer', 'Netherlands', 8, 1, 18)
# ('1924 Winter', 'Switzerland', 8, None, 1)
# ('1928 Summer', 'Finland', 8, 8, 9)
# ('1936 Summer', 'Finland', 8, 6, 13)
# ('1948 Summer', 'Netherlands', 8, 2, 32)
# ('1952 Summer', 'Finland', 8, 3, 29)
# ('1952 Winter', 'Germany', 8, 2, 2)
# ('1956 Summer', 'UK', 8, 16, 22)
# ('1964 Summer', 'Australia', 8, 6, 30)
# ('1968 Winter', 'Italy', 8, None, None)
# ('1972 Summer', 'UK', 8, 9, 12)
# ('1976 Summer', 'Bulgaria', 8, 13, 18)
# ('1980 Summer', 'Bulgaria', 8, 44, 38)
# ('1980 Summer', 'Cuba', 8, 7, 5)
# ('1980 Summer', 'Hungary', 8, 13, 40)
# ('1980 Summer', 'Italy', 8, 21, 8)
# ('1988 Summer', 'Romania', 8, 34, 16)
# ('1988 Winter', 'Switzerland', 8, 7, 5)
# ('1992 Summer', 'Romania', 8, 31, 14)
# ('1992 Summer', 'UK', 8, 3, 39)
# ('1994 Winter', 'Norway', 8, 17, 5)
# ('1996 Summer', 'Canada', 8, 30, 12)
# ('1996 Summer', 'Hungary', 8, 9, 26)
# ('1998 Winter', 'Japan', 8, 1, 4)
# ('2004 Summer', 'Greece', 8, 18, 5)
# ('2004 Summer', 'Ukraine', 8, 8, 31)
# ('2008 Summer', 'Belarus', 8, 5, 16)
# ('2008 Summer', 'Italy', 8, 14, 20)
# ('2012 Summer', 'Jamaica', 8, 9, 8)
# ('2014 Winter', 'Sweden', 8, 32, 11)
# ('2016 Summer', 'Italy', 8, 40, 24)
# ('1908 Summer', 'Hungary', 7, 7, 6)
# ('1908 Summer', 'Norway', 7, 32, 3)
# ('1912 Summer', 'Belgium', 7, 1, 11)
# ('1924 Summer', 'Sweden', 7, 22, 43)
# ('1924 Winter', 'India', 7, None, None)
# ('1928 Summer', 'Canada', 7, 5, 21)
# ('1928 Summer', 'Sweden', 7, 8, 22)
# ('1928 Summer', 'UK', 7, 27, 24)
# ('1936 Summer', 'Sweden', 7, 11, 17)
# ('1936 Winter', 'Norway', 7, 8, 3)
# ('1948 Summer', 'Denmark', 7, 17, 27)
# ('1948 Summer', 'UK', 7, 42, 12)
# ('1948 Winter', 'Sweden', 7, 3, 3)
# ('1952 Summer', 'Australia', 7, 2, 11)
# ('1952 Winter', 'Norway', 7, 6, 6)
# ('1956 Summer', 'France', 7, 13, 13)
# ('1960 Summer', 'Turkey', 7, 2, None)
# ('1960 Winter', 'Russia', 7, 7, 28)
# ('1964 Summer', 'Denmark', 7, 1, 4)
# ('1968 Summer', 'Czech Republic', 7, 7, 15)
# ('1972 Winter', 'Switzerland', 7, 3, 7)
# ('1980 Summer', 'Romania', 7, 15, 46)
# ('1984 Summer', 'Australia', 7, 14, 31)
# ('1984 Winter', 'Sweden', 7, 2, 21)
# ('1988 Winter', 'Finland', 7, 22, 5)
# ('1988 Winter', 'Sweden', 7, None, 23)
# ('1994 Winter', 'South Korea', 7, 1, 1)
# ('1996 Summer', 'Poland', 7, 8, 7)
# ('2000 Summer', 'Poland', 7, 10, 7)
# ('2002 Winter', 'Finland', 7, 5, 1)
# ('2008 Summer', 'Spain', 7, 47, 16)
# ('2012 Summer', 'Japan', 7, 44, 33)
# ('2012 Summer', 'Kazakhstan', 7, 1, 5)
# ('2014 Winter', 'South Korea', 7, 5, 2)
# ('2016 Summer', 'Croatia', 7, 15, 2)
# ('1900 Summer', 'Belgium', 6, 24, 13)
# ('1920 Summer', 'Switzerland', 6, 2, 21)
# ('1928 Summer', 'Denmark', 6, 5, 4)
# ('1928 Winter', 'Norway', 6, 4, 5)
# ('1928 Winter', 'USA', 6, 6, 2)
# ('1936 Summer', 'Austria', 6, 42, 7)
# ('1948 Summer', 'Turkey', 6, 4, 2)
# ('1948 Winter', 'USA', 6, 4, 6)
# ('1952 Winter', 'Finland', 6, 4, 2)
# ('1956 Summer', 'Romania', 6, 3, 10)
# ('1956 Winter', 'Switzerland', 6, 2, 2)
# ('1964 Winter', 'Sweden', 6, 21, 1)
# ('1968 Summer', 'Netherlands', 6, 7, 1)
# ('1972 Summer', 'Bulgaria', 6, 10, 6)
# ('1976 Summer', 'Cuba', 6, 4, 14)
# ('1976 Summer', 'UK', 6, 15, 11)
# ('1980 Summer', 'Australia', 6, 2, 5)
# ('1984 Summer', 'South Korea', 6, 28, 7)
# ('1984 Winter', 'Norway', 6, 5, 4)
# ('1988 Summer', 'China', 6, 16, 30)
# ('1992 Winter', 'Finland', 6, 1, 6)
# ('1994 Winter', 'USA', 6, 8, 5)
# ('1998 Winter', 'South Korea', 6, 4, 2)
# ('1998 Winter', 'Switzerland', 6, 5, 3)
# ('2000 Summer', 'Bahamas', 6, None, 5)
# ('2000 Summer', 'Nigeria', 6, 2, None)
# ('2002 Winter', 'Russia', 6, 5, 27)
# ('2004 Summer', 'Jamaica', 6, 1, 6)
# ('2008 Summer', 'Denmark', 6, 7, 6)
# ('2008 Summer', 'Kenya', 6, 4, 5)
# ('2008 Summer', 'Poland', 6, 13, 1)
# ('2010 Winter', 'Russia', 6, 5, 14)
# ('2010 Winter', 'South Korea', 6, 10, 2)
# ('2010 Winter', 'Switzerland', 6, None, 6)
# ('2012 Summer', 'South Africa', 6, 2, 1)
# ('2014 Winter', 'Switzerland', 6, 4, 20)
# ('2016 Summer', 'Kenya', 6, 6, 1)
# ('2016 Summer', 'New Zealand', 6, 25, 5)
# ('2016 Summer', 'Switzerland', 6, 3, 2)
# ('1896 Summer', 'France', 5, 4, 2)
# ('1904 Summer', 'Cuba', 5, None, None)
# ('1906 Summer', 'Hungary', 5, 5, 3)
# ('1912 Summer', 'Australia', 5, 2, 3)
# ('1912 Summer', 'Denmark', 5, 49, 33)
# ('1912 Summer', 'South Africa', 5, 2, None)
# ('1924 Summer', 'Argentina', 5, 3, 2)
# ('1932 Summer', 'Finland', 5, 8, 16)
# ('1936 Summer', 'Argentina', 5, 2, 4)
# ('1936 Summer', 'Czech Republic', 5, 12, 1)
# ('1936 Summer', 'Switzerland', 5, 23, 24)
# ('1948 Summer', 'Belgium', 5, 2, 8)
# ('1948 Summer', 'Switzerland', 5, 25, 6)
# ('1952 Summer', 'Belgium', 5, 3, None)
# ('1952 Summer', 'Jamaica', 5, 3, None)
# ('1952 Summer', 'Norway', 5, 8, None)
# ('1956 Summer', 'Canada', 5, 9, 5)
# ('1956 Winter', 'Austria', 5, 3, 4)
# ('1956 Winter', 'Finland', 5, 6, 1)
# ('1960 Winter', 'Finland', 5, 3, 5)
# ('1960 Winter', 'Sweden', 5, 2, 2)
# ('1964 Summer', 'Czech Republic', 5, 37, 12)
# ('1964 Summer', 'Netherlands', 5, 10, 16)
# ('1964 Winter', 'Austria', 5, 9, 3)
# ('1968 Summer', 'Australia', 5, 35, 11)
# ('1968 Summer', 'Denmark', 5, 6, 6)
# ('1968 Summer', 'Italy', 5, 8, 20)
# ('1968 Summer', 'New Zealand', 5, None, 2)
# ('1968 Summer', 'Poland', 5, 2, 30)
# ('1968 Summer', 'Romania', 5, 9, 9)
# ('1972 Summer', 'Kenya', 5, 3, 4)
# ('1976 Summer', 'France', 5, 7, 8)
# ('1976 Winter', 'Finland', 5, 10, 1)
# ('1980 Summer', 'UK', 5, 18, 24)
# ('1988 Summer', 'Kenya', 5, 2, 2)
# ('1992 Summer', 'Netherlands', 5, 20, 8)
# ('1992 Summer', 'Poland', 5, 22, 19)
# ('1992 Winter', 'Canada', 5, 28, 3)
# ('1992 Winter', 'France', 5, 6, 1)
# ('1992 Winter', 'South Korea', 5, 1, 1)
# ('1992 Winter', 'USA', 5, 7, 2)
# ('1996 Summer', 'Brazil', 5, 15, 43)
# ('1996 Summer', 'Switzerland', 5, 6, None)
# ('1998 Winter', 'Netherlands', 5, 4, 2)
# ('2000 Summer', 'Bulgaria', 5, 6, 2)
# ('2000 Summer', 'Japan', 5, 31, 8)
# ('2002 Winter', 'France', 5, 5, 5)
# ('2002 Winter', 'South Korea', 5, 2, None)
# ('2002 Winter', 'UK', 5, None, 1)
# ('2004 Summer', 'Norway', 5, None, 2)
# ('2004 Summer', 'Sweden', 5, 5, 2)
# ('2006 Winter', 'Switzerland', 5, 7, 9)
# ('2008 Summer', 'Jamaica', 5, 3, 6)
# ('2008 Summer', 'Romania', 5, 1, 16)
# ('2008 Summer', 'Trinidad', 5, 1, None)
# ('2012 Summer', 'Cuba', 5, 3, 6)
# ('2012 Summer', 'Spain', 5, 33, 25)
# ('2014 Winter', 'Belarus', 5, None, 1)
# ('2016 Summer', 'Cuba', 5, 2, 4)
# ('1900 Summer', 'Denmark', 4, 3, 2)
# ('1904 Summer', 'Germany', 4, 5, 7)
# ('1908 Summer', 'Germany', 4, 11, 6)
# ('1924 Winter', 'Finland', 4, 8, 3)
# ('1924 Winter', 'Norway', 4, 7, 6)
# ('1928 Summer', 'Norway', 4, 4, 1)
# ('1936 Winter', 'Finland', 4, 2, 3)
# ('1936 Winter', 'Germany', 4, 3, None)
# ('1936 Winter', 'Switzerland', 4, 6, None)
# ('1948 Summer', 'Mexico', 4, 1, 4)
# ('1948 Winter', 'Norway', 4, 3, 6)
# ('1948 Winter', 'Switzerland', 4, 5, 19)
# ('1952 Summer', 'Serbia', 4, 20, None)
# ('1952 Winter', 'USA', 4, 25, 1)
# ('1956 Summer', 'Japan', 4, 15, 5)
# ('1960 Summer', 'Czech Republic', 4, 7, 11)
# ('1960 Summer', 'Poland', 4, 11, 15)
# ('1960 Winter', 'Germany', 4, 4, 1)
# ('1964 Summer', 'New Zealand', 4, None, 2)
# ('1964 Summer', 'UK', 4, 19, 5)
# ('1964 Winter', 'Canada', 4, 2, 1)
# ('1968 Summer', 'Norway', 4, 2, None)
# ('1968 Summer', 'Sweden', 4, 4, 1)
# ('1968 Winter', 'France', 4, 3, 2)
# ('1968 Winter', 'Germany', 4, 5, 7)
# ('1972 Summer', 'Sweden', 4, 10, 8)
# ('1972 Winter', 'Netherlands', 4, 3, 2)
# ('1976 Summer', 'Finland', 4, 2, None)
# ('1976 Summer', 'Romania', 4, 28, 23)
# ('1980 Summer', 'Brazil', 4, None, 5)
# ('1980 Summer', 'Denmark', 4, 2, 2)
# ('1984 Summer', 'Finland', 4, 2, 6)
# ('1984 Winter', 'Finland', 4, 3, 12)
# ('1984 Winter', 'USA', 4, 5, None)
# ('1988 Summer', 'Canada', 4, 5, 14)
# ('1988 Summer', 'Japan', 4, 3, 13)
# ('1988 Summer', 'New Zealand', 4, 4, 16)
# ('1992 Summer', 'Czech Republic', 4, 3, 1)
# ('1992 Summer', 'North Korea', 4, None, 6)
# ('1992 Winter', 'Italy', 4, 9, 8)
# ('1994 Winter', 'Switzerland', 4, 8, 4)
# ('1996 Summer', 'Czech Republic', 4, 5, 4)
# ('1996 Summer', 'Greece', 4, 4, None)
# ('1996 Summer', 'Turkey', 4, 1, 1)
# ('2000 Summer', 'Canada', 4, 4, 23)
# ('2000 Summer', 'Ethiopia', 4, 1, 3)
# ('2000 Summer', 'Greece', 4, 6, 8)
# ('2000 Summer', 'Sweden', 4, 20, 8)
# ('2002 Winter', 'Italy', 4, 11, 6)
# ('2004 Summer', 'Netherlands', 4, 51, 22)
# ('2004 Summer', 'New Zealand', 4, 2, None)
# ('2004 Summer', 'Poland', 4, 2, 6)
# ('2004 Summer', 'South Africa', 4, 3, 3)
# ('2004 Summer', 'Spain', 4, 17, 9)
# ('2008 Summer', 'Ethiopia', 4, 1, 2)
# ('2008 Summer', 'New Zealand', 4, 2, 9)
# ('2008 Summer', 'Slovakia', 4, 5, 1)
# ('2010 Winter', 'Netherlands', 4, 1, 6)
# ('2012 Summer', 'Bahamas', 4, None, None)
# ('2012 Summer', 'Czech Republic', 4, 4, 6)
# ('2012 Summer', 'Iran', 4, 5, 3)
# ('2012 Summer', 'North Korea', 4, None, 2)
# ('2014 Winter', 'Austria', 4, 12, 11)
# ('2014 Winter', 'France', 4, 4, 10)
# ('2014 Winter', 'Poland', 4, 4, 3)
# ('2014 Winter', 'Ukraine', 4, None, 1)
# ('2016 Summer', 'Canada', 4, 4, 61)
# ('2016 Summer', 'Romania', 4, 2, 10)
# ('2016 Summer', 'Uzbekistan', 4, 2, 7)
# ('1896 Summer', 'UK', 3, 3, 3)
# ('1900 Summer', 'Australia', 3, None, 3)
# ('1900 Summer', 'Italy', 3, 2, None)
# ('1900 Summer', 'Netherlands', 3, 8, 16)
# ('1900 Summer', 'Sweden', 3, None, 1)
# ('1906 Summer', 'Austria', 3, 3, 3)
# ('1912 Summer', 'Canada', 3, 2, 3)
# ('1920 Summer', 'South Africa', 3, 12, 6)
# ('1924 Summer', 'Australia', 3, 5, 2)
# ('1924 Summer', 'Belgium', 3, 30, 6)
# ('1924 Winter', 'Austria', 3, 1, None)
# ('1928 Summer', 'Argentina', 3, 18, 5)
# ('1928 Summer', 'Austria', 3, None, 2)
# ('1928 Summer', 'Spain', 3, None, None)
# ('1932 Summer', 'Argentina', 3, 1, None)
# ('1932 Summer', 'Australia', 3, 1, 1)
# ('1932 Summer', 'Poland', 3, 4, 14)
# ('1932 Winter', 'Norway', 3, 4, 3)
# ('1948 Summer', 'Argentina', 3, 7, 1)
# ('1948 Summer', 'Norway', 3, 4, 11)
# ('1952 Summer', 'Denmark', 3, 1, 5)
# ('1952 Summer', 'UK', 3, 2, 26)
# ('1956 Summer', 'Finland', 3, 1, 22)
# ('1956 Summer', 'New Zealand', 3, None, None)
# ('1956 Summer', 'Turkey', 3, 2, 2)
# ('1960 Summer', 'Greece', 3, None, None)
# ('1960 Summer', 'Romania', 3, 1, 11)
# ('1960 Winter', 'Canada', 3, 17, 1)
# ('1960 Winter', 'Norway', 3, 6, None)
# ('1964 Summer', 'Bulgaria', 3, 5, 2)
# ('1964 Summer', 'Finland', 3, None, 2)
# ('1964 Summer', 'Sweden', 3, 4, 8)
# ('1964 Winter', 'Finland', 3, 7, 5)
# ('1964 Winter', 'France', 3, 4, None)
# ('1964 Winter', 'Germany', 3, 4, 3)
# ('1964 Winter', 'Norway', 3, 6, 6)
# ('1968 Summer', 'Canada', 3, 3, 4)
# ('1968 Summer', 'Kenya', 3, 7, 2)
# ('1968 Summer', 'Mexico', 3, 3, 3)
# ('1968 Winter', 'Austria', 3, 8, 4)
# ('1968 Winter', 'Netherlands', 3, 3, 3)
# ('1968 Winter', 'Sweden', 3, 7, 6)
# ('1972 Summer', 'Cuba', 3, 1, 18)
# ('1972 Summer', 'Finland', 3, 1, 6)
# ('1972 Summer', 'Netherlands', 3, 1, 2)
# ('1972 Summer', 'Romania', 3, 10, 27)
# ('1972 Winter', 'Italy', 3, 5, 1)
# ('1972 Winter', 'USA', 3, 18, 3)
# ('1976 Summer', 'Denmark', 3, None, 5)
# ('1976 Winter', 'Norway', 3, 6, 1)
# ('1976 Winter', 'USA', 3, 3, 5)
# ('1980 Summer', 'Finland', 3, 1, 5)
# ('1980 Summer', 'Poland', 3, 25, 22)
# ('1980 Summer', 'Sweden', 3, 8, 9)
# ('1980 Winter', 'Austria', 3, 2, 3)
# ('1980 Winter', 'Sweden', 3, None, 20)
# ('1984 Summer', 'Sweden', 3, 18, 13)
# ('1988 Summer', 'Czech Republic', 3, 4, 3)
# ('1988 Summer', 'Denmark', 3, 1, 3)
# ('1988 Summer', 'Netherlands', 3, 6, 36)
# ('1988 Winter', 'Austria', 3, 5, 4)
# ('1988 Winter', 'Netherlands', 3, 2, 2)
# ('1992 Summer', 'Bulgaria', 3, 7, 7)
# ('1992 Summer', 'Denmark', 3, 2, 9)
# ('1992 Summer', 'Japan', 3, 8, 36)
# ('1992 Winter', 'Japan', 3, 2, 7)
# ('1994 Winter', 'Canada', 3, 29, 5)
# ('1994 Winter', 'Japan', 3, 5, 2)
# ('1996 Summer', 'Bulgaria', 3, 12, 6)
# ('1996 Summer', 'Ireland', 3, None, 1)
# ('1996 Summer', 'Japan', 3, 26, 13)
# ('1996 Summer', 'Kazakhstan', 3, 4, 4)
# ('1996 Summer', 'New Zealand', 3, 2, 4)
# ('1996 Summer', 'South Africa', 3, 1, 1)
# ('1996 Summer', 'Sweden', 3, 23, 5)
# ('1998 Winter', 'Austria', 3, 5, 12)
# ('1998 Winter', 'Italy', 3, 9, 5)
# ('2000 Summer', 'Austria', 3, 1, None)
# ('2000 Summer', 'Belarus', 3, 8, 11)
# ('2000 Summer', 'Finland', 3, 1, 1)
# ('2000 Summer', 'Iran', 3, None, 1)
# ('2000 Summer', 'Kazakhstan', 3, 4, None)
# ('2000 Summer', 'Slovenia', 3, None, None)
# ('2000 Summer', 'Spain', 3, 19, 20)
# ('2000 Summer', 'Turkey', 3, None, 2)
# ('2000 Summer', 'Ukraine', 3, 20, 12)
# ('2002 Winter', 'Austria', 3, 4, 13)
# ('2002 Winter', 'Croatia', 3, 1, None)
# ('2002 Winter', 'Netherlands', 3, 5, None)
# ('2002 Winter', 'Switzerland', 3, 7, 14)
# ('2004 Summer', 'Austria', 3, 4, 1)
# ('2004 Summer', 'Canada', 3, 10, 4)
# ('2004 Summer', 'Chile', 3, None, 1)
# ('2004 Summer', 'Slovakia', 3, 2, 5)
# ('2004 Summer', 'Thailand', 3, 1, 4)
# ('2004 Summer', 'Turkey', 3, 3, 5)
# ('2006 Winter', 'Estonia', 3, None, None)
# ('2006 Winter', 'France', 3, 2, 10)
# ('2006 Winter', 'Netherlands', 3, 2, 8)
# ('2008 Summer', 'Czech Republic', 3, 4, None)
# ('2008 Summer', 'Georgia', 3, None, 3)
# ('2008 Summer', 'Switzerland', 3, 1, 7)
# ('2012 Summer', 'Belarus', 3, 12, 8)
# ('2012 Summer', 'Denmark', 3, 5, 8)
# ('2012 Summer', 'Ethiopia', 3, 1, 3)
# ('2014 Winter', 'China', 3, 4, 5)
# ('2016 Summer', 'Colombia', 3, 2, 3)
# ('2016 Summer', 'Greece', 3, 1, 3)
# ('2016 Summer', 'Iran', 3, 1, 4)
# ('2016 Summer', 'Kazakhstan', 3, 5, 10)
# ('2016 Summer', 'Poland', 3, 3, 10)
# ('2016 Summer', 'Slovakia', 3, 5, None)
# ('1896 Summer', 'Australia', 2, None, 1)
# ('1896 Summer', 'Austria', 2, 1, 2)
# ('1896 Summer', 'Hungary', 2, 1, 3)
# ('1900 Summer', 'Spain', 2, None, None)
# ('1904 Summer', 'Austria', 2, 1, 1)
# ('1904 Summer', 'Hungary', 2, 1, 1)
# ('1904 Summer', 'Norway', 2, None, None)
# ('1906 Summer', 'Belgium', 2, 3, 6)
# ('1906 Summer', 'Finland', 2, 1, 1)
# ('1906 Summer', 'Sweden', 2, 5, 14)
# ('1908 Summer', 'Italy', 2, 6, None)
# ('1912 Summer', 'Switzerland', 2, None, None)
# ('1924 Summer', 'Denmark', 2, 9, 3)
# ('1924 Summer', 'Hungary', 2, 12, 8)
# ('1924 Summer', 'Serbia', 2, None, None)
# ('1928 Summer', 'Czech Republic', 2, 12, 2)
# ('1928 Summer', 'Egypt', 2, 1, 1)
# ('1928 Summer', 'Estonia', 2, 1, 6)
# ('1928 Summer', 'Japan', 2, 6, 1)
# ('1928 Summer', 'Poland', 2, 3, 15)
# ('1928 Winter', 'Finland', 2, 1, 1)
# ('1928 Winter', 'France', 2, None, None)
# ('1928 Winter', 'Sweden', 2, 13, 1)
# ('1932 Summer', 'Canada', 2, 13, 24)
# ('1932 Summer', 'Ireland', 2, None, None)
# ('1932 Summer', 'Netherlands', 2, 10, 1)
# ('1932 Summer', 'South Africa', 2, None, 3)
# ('1932 Winter', 'France', 2, None, None)
# ('1936 Summer', 'Egypt', 2, 1, 2)
# ('1936 Summer', 'Estonia', 2, 2, 3)
# ('1936 Winter', 'Sweden', 2, 2, 6)
# ('1936 Winter', 'USA', 2, None, 14)
# ('1948 Summer', 'Australia', 2, 9, 5)
# ('1948 Summer', 'Austria', 2, 2, 4)
# ('1948 Summer', 'Egypt', 2, 2, 1)
# ('1948 Summer', 'South Africa', 2, 2, 2)
# ('1948 Winter', 'Belgium', 2, 4, None)
# ('1948 Winter', 'France', 2, 1, 2)
# ('1952 Summer', 'Argentina', 2, 2, 2)
# ('1952 Summer', 'South Africa', 2, 8, 4)
# ('1952 Summer', 'Switzerland', 2, 19, 12)
# ('1952 Summer', 'Turkey', 2, None, 1)
# ('1952 Winter', 'Austria', 2, 4, 2)
# ('1956 Summer', 'Iran', 2, 2, 1)
# ('1956 Winter', 'Italy', 2, 6, None)
# ('1956 Winter', 'Norway', 2, 1, 1)
# ('1956 Winter', 'Sweden', 2, 4, 9)
# ('1956 Winter', 'USA', 2, 19, 5)
# ('1960 Summer', 'Denmark', 2, 17, 4)
# ('1960 Summer', 'New Zealand', 2, None, 1)
# ('1960 Summer', 'Norway', 2, None, None)
# ('1960 Summer', 'Sweden', 2, 2, 3)
# ('1960 Summer', 'UK', 2, 11, 15)
# ('1960 Winter', 'Switzerland', 2, None, None)
# ('1964 Summer', 'Bahamas', 2, None, None)
# ('1964 Summer', 'Belgium', 2, None, 1)
# ('1964 Summer', 'Canada', 2, 2, 1)
# ('1964 Summer', 'Romania', 2, 4, 10)
# ('1964 Summer', 'Serbia', 2, 11, 2)
# ('1964 Summer', 'Turkey', 2, 3, 1)
# ('1964 Winter', 'UK', 2, None, None)
# ('1968 Summer', 'Bulgaria', 2, 21, 3)
# ('1968 Summer', 'Iran', 2, 1, 2)
# ('1968 Summer', 'Turkey', 2, None, None)
# ('1972 Summer', 'Czech Republic', 2, 21, 6)
# ('1972 Summer', 'France', 2, 5, 15)
# ('1972 Summer', 'Norway', 2, 2, 4)
# ('1972 Winter', 'Norway', 2, 8, 7)
# ('1976 Summer', 'Czech Republic', 2, 4, 9)
# ('1976 Summer', 'Italy', 2, 25, 4)
# ('1976 Summer', 'Norway', 2, 4, None)
# ('1976 Summer', 'Serbia', 2, 14, 3)
# ('1976 Winter', 'Austria', 2, 2, 3)
# ('1980 Summer', 'Ethiopia', 2, None, 2)
# ('1980 Summer', 'Spain', 2, 19, 3)
# ('1980 Summer', 'Switzerland', 2, None, None)
# ('1980 Winter', 'Liechtenstein', 2, 2, None)
# ('1980 Winter', 'Switzerland', 2, 4, 3)
# ('1984 Summer', 'Mexico', 2, 3, 1)
# ('1984 Summer', 'Morocco', 2, None, None)
# ('1984 Summer', 'Spain', 2, 14, 3)
# ('1984 Winter', 'Canada', 2, 1, 1)
# ('1984 Winter', 'Italy', 2, None, None)
# ('1984 Winter', 'Switzerland', 2, 2, 4)
# ('1984 Winter', 'UK', 2, None, None)
# ('1988 Summer', 'Norway', 2, 20, None)
# ('1988 Summer', 'Poland', 2, 9, 10)
# ('1988 Winter', 'Italy', 2, 1, 5)
# ('1988 Winter', 'USA', 2, 1, 4)
# ('1992 Summer', 'Greece', 2, None, None)
# ('1992 Summer', 'Indonesia', 2, 3, 1)
# ('1992 Summer', 'Kenya', 2, 4, 2)
# ('1992 Summer', 'Norway', 2, 20, 1)
# ('1992 Summer', 'Turkey', 2, 2, 2)
# ('1992 Winter', 'Switzerland', 2, None, 5)
# ('1994 Winter', 'Austria', 2, 3, 7)
# ('1996 Summer', 'Algeria', 2, None, 1)
# ('1996 Summer', 'Belgium', 2, 2, 2)
# ('1996 Summer', 'Ethiopia', 2, None, 1)
# ('1996 Summer', 'Indonesia', 2, 1, 3)
# ('1996 Summer', 'North Korea', 2, 1, 2)
# ('1996 Summer', 'Norway', 2, 3, 18)
# ('1996 Summer', 'UK', 2, 15, 9)
# ('1998 Winter', 'Finland', 2, 7, 49)
# ('1998 Winter', 'France', 2, 1, 12)
# ('2000 Summer', 'Azerbaijan', 2, None, 1)
# ('2000 Summer', 'Czech Republic', 2, 3, 4)
# ('2000 Summer', 'Indonesia', 2, 4, 2)
# ('2000 Summer', 'Kenya', 2, 3, 2)
# ('2000 Summer', 'Lithuania', 2, None, 15)
# ('2000 Summer', 'Slovakia', 2, 3, 1)
# ('2002 Winter', 'Australia', 2, None, None)
# ('2002 Winter', 'China', 2, 5, 9)
# ('2004 Summer', 'Belarus', 2, 5, 8)
# ('2004 Summer', 'Bulgaria', 2, 1, 14)
# ('2004 Summer', 'Ethiopia', 2, 3, 2)
# ('2004 Summer', 'Georgia', 2, 2, None)
# ('2004 Summer', 'Iran', 2, 2, 2)
# ('2004 Summer', 'Morocco', 2, 1, None)
# ('2004 Summer', 'Taiwan', 2, 4, 3)
# ('2004 Summer', 'Uzbekistan', 2, 1, 2)
# ('2006 Winter', 'China', 2, 5, 6)
# ('2006 Winter', 'Norway', 2, 9, 12)
# ('2008 Summer', 'Cuba', 2, 34, 11)
# ('2008 Summer', 'Indonesia', 2, 2, 3)
# ('2008 Summer', 'Kazakhstan', 2, 4, 7)
# ('2008 Summer', 'Mexico', 2, None, 2)
# ('2008 Summer', 'Mongolia', 2, 2, None)
# ('2008 Summer', 'North Korea', 2, 1, 3)
# ('2008 Summer', 'Thailand', 2, 2, None)
# ('2010 Winter', 'Australia', 2, 1, None)
# ('2010 Winter', 'Czech Republic', 2, None, 7)
# ('2010 Winter', 'France', 2, 6, 6)
# ('2012 Summer', 'Azerbaijan', 2, 2, 6)
# ('2012 Summer', 'Kenya', 2, 4, 5)
# ('2012 Summer', 'Lithuania', 2, 1, 2)
# ('2012 Summer', 'Poland', 2, 2, 8)
# ('2012 Summer', 'Romania', 2, 8, 6)
# ('2012 Summer', 'Sweden', 2, 17, 3)
# ('2012 Summer', 'Switzerland', 2, 2, None)
# ('2012 Summer', 'Turkey', 2, 2, 1)
# ('2014 Winter', 'Czech Republic', 2, 7, 2)
# ('2014 Winter', 'Finland', 2, 7, 24)
# ('2014 Winter', 'Slovenia', 2, 2, 4)
# ('2016 Summer', 'Belgium', 2, 17, 2)
# ('2016 Summer', 'Georgia', 2, 1, 4)
# ('2016 Summer', 'Indonesia', 2, 2, None)
# ('2016 Summer', 'North Korea', 2, 3, 2)
# ('2016 Summer', 'South Africa', 2, 7, 14)
# ('2016 Summer', 'Sweden', 2, 23, 3)
# ('2016 Summer', 'Thailand', 2, 2, 2)
# ('2016 Summer', 'Ukraine', 2, 8, 5)
# ('1896 Summer', 'Denmark', 1, 2, 3)
# ('1896 Summer', 'Switzerland', 1, 2, None)
# ('1900 Summer', 'Canada', 1, None, 1)
# ('1900 Summer', 'Cuba', 1, 1, None)
# ('1900 Summer', 'Haiti', 1, None, None)
# ('1900 Summer', 'Hungary', 1, 2, 2)
# ('1900 Summer', 'Luxembourg', 1, None, None)
# ('1900 Summer', 'New Zealand', 1, None, None)
# ('1904 Summer', 'Greece', 1, None, 1)
# ('1904 Summer', 'Switzerland', 1, None, 2)
# ('1904 Summer', 'UK', 1, 1, None)
# ('1906 Summer', 'Canada', 1, 1, None)
# ('1908 Summer', 'Belgium', 1, 24, 8)
# ('1908 Summer', 'Finland', 1, 1, 28)
# ('1908 Summer', 'Russia', 1, 2, None)
# ('1908 Summer', 'South Africa', 1, 1, None)
# ('1912 Summer', 'Greece', 1, None, 1)
# ('1920 Summer', 'Brazil', 1, 1, 5)
# ('1920 Summer', 'Estonia', 1, 2, None)
# ('1924 Summer', 'Czech Republic', 1, 4, 5)
# ('1924 Summer', 'Estonia', 1, 1, 4)
# ('1924 Summer', 'Greece', 1, None, None)
# ('1924 Summer', 'Luxembourg', 1, 1, None)
# ('1924 Summer', 'South Africa', 1, 1, 1)
# ('1924 Winter', 'Australia', 1, None, None)
# ('1924 Winter', 'Nepal', 1, None, None)
# ('1924 Winter', 'Sweden', 1, 8, None)
# ('1924 Winter', 'USA', 1, 10, 1)
# ('1928 Summer', 'Australia', 1, 2, 1)
# ('1928 Summer', 'Ireland', 1, None, None)
# ('1928 Summer', 'Luxembourg', 1, None, None)
# ('1928 Summer', 'New Zealand', 1, None, None)
# ('1928 Summer', 'Serbia', 1, 1, 10)
# ('1928 Summer', 'South Africa', 1, None, 5)
# ('1932 Summer', 'Austria', 1, 1, 3)
# ('1932 Summer', 'Czech Republic', 1, 3, 2)
# ('1932 Winter', 'Austria', 1, 1, None)
# ('1932 Winter', 'Finland', 1, 1, 1)
# ('1932 Winter', 'Sweden', 1, 2, None)
# ('1936 Summer', 'Canada', 1, 12, 9)
# ('1936 Summer', 'New Zealand', 1, None, None)
# ('1936 Summer', 'Norway', 1, 12, 15)
# ('1936 Summer', 'Turkey', 1, None, 1)
# ('1936 Winter', 'Austria', 1, 2, 2)
# ('1948 Summer', 'Jamaica', 1, 2, None)
# ('1948 Summer', 'Peru', 1, None, None)
# ('1948 Summer', 'Poland', 1, None, 1)
# ('1948 Winter', 'Austria', 1, 3, 4)
# ('1948 Winter', 'Finland', 1, 6, 2)
# ('1948 Winter', 'Italy', 1, None, None)
# ('1952 Summer', 'Brazil', 1, None, 2)
# ('1952 Summer', 'Canada', 1, 3, None)
# ('1952 Summer', 'Japan', 1, 9, 2)
# ('1952 Summer', 'Luxembourg', 1, None, None)
# ('1952 Summer', 'New Zealand', 1, None, 2)
# ('1952 Summer', 'Poland', 1, 2, 1)
# ('1952 Summer', 'Romania', 1, 1, 2)
# ('1952 Winter', 'Italy', 1, None, 1)
# ('1952 Winter', 'UK', 1, None, None)
# ('1956 Summer', 'Brazil', 1, None, None)
# ('1956 Summer', 'Bulgaria', 1, 3, 14)
# ('1956 Summer', 'Czech Republic', 1, 5, 1)
# ('1956 Summer', 'Denmark', 1, 4, 1)
# ('1956 Summer', 'Ireland', 1, 1, 3)
# ('1956 Summer', 'Mexico', 1, None, 1)
# ('1956 Summer', 'Norway', 1, None, 2)
# ('1956 Summer', 'Poland', 1, 9, 9)
# ('1956 Winter', 'Germany', 1, None, 1)
# ('1960 Summer', 'Austria', 1, 2, None)
# ('1960 Summer', 'Bulgaria', 1, 3, 3)
# ('1960 Summer', 'Ethiopia', 1, None, None)
# ('1960 Summer', 'Finland', 1, 1, 4)
# ('1960 Winter', 'Austria', 1, 2, 3)
# ('1960 Winter', 'France', 1, None, 2)
# ('1964 Summer', 'Ethiopia', 1, None, None)
# ('1964 Summer', 'France', 1, 13, 17)
# ('1964 Summer', 'Switzerland', 1, 4, 1)
# ('1964 Winter', 'Netherlands', 1, 1, None)
# ('1964 Winter', 'USA', 1, 2, 5)
# ('1968 Summer', 'Ethiopia', 1, 1, None)
# ('1968 Summer', 'Finland', 1, 2, 1)
# ('1968 Summer', 'Tunisia', 1, None, 1)
# ('1968 Summer', 'Venezuela', 1, None, None)
# ('1968 Winter', 'Canada', 1, 1, 18)
# ('1968 Winter', 'Czech Republic', 1, 19, 1)
# ('1968 Winter', 'Finland', 1, 2, 5)
# ('1968 Winter', 'USA', 1, 5, 1)
# ('1972 Summer', 'Denmark', 1, None, None)
# ('1972 Summer', 'North Korea', 1, 1, 13)
# ('1972 Summer', 'Uganda', 1, 1, None)
# ('1972 Winter', 'Austria', 1, 2, 2)
# ('1972 Winter', 'Czech Republic', 1, None, 19)
# ('1972 Winter', 'Japan', 1, 1, 1)
# ('1972 Winter', 'Poland', 1, None, None)
# ('1972 Winter', 'Spain', 1, None, None)
# ('1972 Winter', 'Sweden', 1, 1, 2)
# ('1976 Summer', 'Jamaica', 1, 1, None)
# ('1976 Summer', 'Mexico', 1, None, 1)
# ('1976 Summer', 'North Korea', 1, 1, None)
# ('1976 Summer', 'South Korea', 1, 1, 15)
# ('1976 Summer', 'Switzerland', 1, 3, 6)
# ('1976 Summer', 'Trinidad', 1, None, None)
# ('1976 Winter', 'Canada', 1, 1, 1)
# ('1976 Winter', 'Italy', 1, 2, 1)
# ('1976 Winter', 'Netherlands', 1, 2, 3)
# ('1976 Winter', 'Switzerland', 1, 6, 2)
# ('1976 Winter', 'UK', 1, None, None)
# ('1980 Summer', 'Austria', 1, 3, 1)
# ('1980 Summer', 'Belgium', 1, None, None)
# ('1980 Summer', 'Greece', 1, None, 4)
# ('1980 Winter', 'Finland', 1, 5, 6)
# ('1980 Winter', 'Netherlands', 1, 2, 1)
# ('1980 Winter', 'Norway', 1, 5, 9)
# ('1980 Winter', 'UK', 1, None, None)
# ('1984 Summer', 'Austria', 1, 1, 1)
# ('1984 Summer', 'Belgium', 1, 2, 2)
# ('1984 Summer', 'Brazil', 1, 33, 2)
# ('1984 Summer', 'Kenya', 1, None, 2)
# ('1984 Summer', 'Portugal', 1, None, 2)
# ('1988 Summer', 'Austria', 1, None, None)
# ('1988 Summer', 'Brazil', 1, 17, 5)
# ('1988 Summer', 'Finland', 1, 1, 2)
# ('1988 Summer', 'Morocco', 1, None, 2)
# ('1988 Summer', 'Portugal', 1, None, None)
# ('1988 Summer', 'Spain', 1, 2, 2)
# ('1988 Summer', 'Suriname', 1, None, None)
# ('1988 Summer', 'Turkey', 1, 1, None)
# ('1988 Winter', 'France', 1, None, 1)
# ('1992 Summer', 'Algeria', 1, None, 1)
# ('1992 Summer', 'Estonia', 1, None, 2)
# ('1992 Summer', 'Ethiopia', 1, None, 2)
# ('1992 Summer', 'Finland', 1, 4, 2)
# ('1992 Summer', 'Ireland', 1, 1, None)
# ('1992 Summer', 'Lithuania', 1, None, 12)
# ('1992 Summer', 'Morocco', 1, 1, 1)
# ('1992 Summer', 'New Zealand', 1, 9, 5)
# ('1992 Summer', 'Sweden', 1, 27, 7)
# ('1992 Summer', 'Switzerland', 1, None, None)
# ('1992 Winter', 'Netherlands', 1, 1, 2)
# ('1992 Winter', 'Sweden', 1, None, 6)
# ('1994 Winter', 'Kazakhstan', 1, 2, None)
# ('1994 Winter', 'Ukraine', 1, None, 1)
# ('1994 Winter', 'Uzbekistan', 1, None, None)
# ('1996 Summer', 'Armenia', 1, 1, None)
# ('1996 Summer', 'Belarus', 1, 6, 16)
# ('1996 Summer', 'Burundi', 1, None, None)
# ('1996 Summer', 'Costa Rica', 1, None, None)
# ('1996 Summer', 'Ecuador', 1, None, None)
# ('1996 Summer', 'Finland', 1, 2, 1)
# ('1996 Summer', 'Iran', 1, 1, 1)
# ('1996 Summer', 'Jamaica', 1, 3, 12)
# ('1996 Summer', 'Kenya', 1, 4, 3)
# ('1996 Summer', 'Portugal', 1, None, 2)
# ('1996 Summer', 'Serbia', 1, 12, 13)
# ('1996 Summer', 'Slovakia', 1, 1, 1)
# ('1996 Summer', 'Syria', 1, None, None)
# ('1996 Summer', 'Thailand', 1, None, 1)
# ('1998 Winter', 'Bulgaria', 1, None, None)
# ('2000 Summer', 'Algeria', 1, 1, 3)
# ('2000 Summer', 'Colombia', 1, None, None)
# ('2000 Summer', 'Croatia', 1, None, 9)
# ('2000 Summer', 'Estonia', 1, None, 2)
# ('2000 Summer', 'Latvia', 1, 1, 1)
# ('2000 Summer', 'Mexico', 1, 2, 3)
# ('2000 Summer', 'Mozambique', 1, None, None)
# ('2000 Summer', 'New Zealand', 1, None, 3)
# ('2000 Summer', 'Switzerland', 1, 11, 2)
# ('2000 Summer', 'Thailand', 1, None, 2)
# ('2000 Summer', 'Uzbekistan', 1, 1, 2)
# ('2002 Winter', 'Czech Republic', 1, 2, None)
# ('2002 Winter', 'Estonia', 1, 1, 1)
# ('2004 Summer', 'Azerbaijan', 1, None, 4)
# ('2004 Summer', 'Bahamas', 1, None, 1)
# ('2004 Summer', 'Belgium', 1, None, 2)
# ('2004 Summer', 'Cameroon', 1, None, None)
# ('2004 Summer', 'Czech Republic', 1, 6, 6)
# ('2004 Summer', 'Dominican Republic', 1, None, None)
# ('2004 Summer', 'Egypt', 1, 1, 3)
# ('2004 Summer', 'Indonesia', 1, 1, 3)
# ('2004 Summer', 'Israel', 1, None, 1)
# ('2004 Summer', 'Kazakhstan', 1, 4, 3)
# ('2004 Summer', 'Kenya', 1, 4, 2)
# ('2004 Summer', 'Lithuania', 1, 2, None)
# ('2004 Summer', 'Switzerland', 1, 2, 4)
# ('2004 Summer', 'United Arab Emirates', 1, None, None)
# ('2004 Summer', 'Zimbabwe', 1, 1, 1)
# ('2006 Winter', 'Australia', 1, None, 1)
# ('2006 Winter', 'Croatia', 1, 2, None)
# ('2006 Winter', 'Czech Republic', 1, 2, 24)
# ('2006 Winter', 'Japan', 1, None, None)
# ('2008 Summer', 'Azerbaijan', 1, 2, 4)
# ('2008 Summer', 'Belgium', 1, 4, None)
# ('2008 Summer', 'Bulgaria', 1, 1, 3)
# ('2008 Summer', 'Cameroon', 1, None, None)
# ('2008 Summer', 'Dominican Republic', 1, 1, None)
# ('2008 Summer', 'Estonia', 1, 2, None)
# ('2008 Summer', 'Finland', 1, 2, 2)
# ('2008 Summer', 'India', 1, None, 2)
# ('2008 Summer', 'Iran', 1, None, 1)
# ('2008 Summer', 'Latvia', 1, 1, 1)
# ('2008 Summer', 'Panama', 1, None, None)
# ('2008 Summer', 'Portugal', 1, 1, None)
# ('2008 Summer', 'Slovenia', 1, 2, 2)
# ('2008 Summer', 'Tunisia', 1, None, None)
# ('2008 Summer', 'Turkey', 1, 3, 3)
# ('2008 Summer', 'Uzbekistan', 1, 2, 3)
# ('2008 Summer', 'Zimbabwe', 1, 3, None)
# ('2010 Winter', 'Belarus', 1, 1, 1)
# ('2010 Winter', 'Italy', 1, 1, 3)
# ('2010 Winter', 'Poland', 1, 3, 4)
# ('2010 Winter', 'Slovakia', 1, 1, 1)
# ('2010 Winter', 'UK', 1, None, None)
# ('2012 Summer', 'Algeria', 1, None, None)
# ('2012 Summer', 'Argentina', 1, 15, 3)
# ('2012 Summer', 'Canada', 1, 21, 33)
# ('2012 Summer', 'Colombia', 1, 3, 4)
# ('2012 Summer', 'Dominican Republic', 1, 1, None)
# ('2012 Summer', 'Georgia', 1, 3, 3)
# ('2012 Summer', 'Grenada', 1, None, None)
# ('2012 Summer', 'Ireland', 1, 1, 3)
# ('2012 Summer', 'Latvia', 1, None, 2)
# ('2012 Summer', 'Serbia', 1, 1, 14)
# ('2012 Summer', 'Slovenia', 1, 1, 3)
# ('2012 Summer', 'Trinidad', 1, 4, 5)
# ('2012 Summer', 'Tunisia', 1, 1, 1)
# ('2012 Summer', 'Uganda', 1, None, None)
# ('2012 Summer', 'Uzbekistan', 1, None, 2)
# ('2012 Summer', 'Venezuela', 1, None, None)
# ('2014 Winter', 'Japan', 1, 4, 6)
# ('2014 Winter', 'Slovakia', 1, None, None)
# ('2014 Winter', 'UK', 1, 4, 5)
# ('2016 Summer', 'Armenia', 1, 3, None)
# ('2016 Summer', 'Azerbaijan', 1, 7, 10)
# ('2016 Summer', 'Bahamas', 1, None, 5)
# ('2016 Summer', 'Bahrain', 1, 1, None)
# ('2016 Summer', 'Belarus', 1, 4, 7)
# ('2016 Summer', 'Czech Republic', 1, 2, 12)
# ('2016 Summer', 'Ethiopia', 1, 2, 5)
# ('2016 Summer', 'Individual Olympic Athletes', 1, None, 1)
# ('2016 Summer', 'Ivory Coast', 1, None, 1)
# ('2016 Summer', 'Jordan', 1, None, None)
# ('2016 Summer', 'Kosovo', 1, None, None)
# ('2016 Summer', 'Puerto Rico', 1, None, None)
# ('2016 Summer', 'Slovenia', 1, 2, 1)
# ('2016 Summer', 'Taiwan', 1, None, 4)
# ('2016 Summer', 'Tajikistan', 1, None, None)
# ('2016 Summer', 'Turkey', 1, 3, 4)
# ('2016 Summer', 'Vietnam', 1, 1, None)
# ('1896 Summer', 'Italy', None, None, None)
# ('1896 Summer', 'Sweden', None, None, None)
# ('1900 Summer', 'Argentina', None, None, None)
# ('1900 Summer', 'Austria', None, 3, 3)
# ('1900 Summer', 'Brazil', None, None, None)
# ('1900 Summer', 'Colombia', None, 1, None)
# ('1900 Summer', 'Czech Republic', None, 1, 2)
# ('1900 Summer', 'Greece', None, None, None)
# ('1900 Summer', 'India', None, 2, None)
# ('1900 Summer', 'Iran', None, None, None)
# ('1900 Summer', 'Mexico', None, None, 3)
# ('1900 Summer', 'Norway', None, 6, 3)
# ('1900 Summer', 'Peru', None, None, None)
# ('1900 Summer', 'Romania', None, None, None)
# ('1900 Summer', 'Russia', None, None, None)
# ('1904 Summer', 'Australia', None, 3, 1)
# ('1904 Summer', 'France', None, 2, None)
# ('1904 Summer', 'Italy', None, None, None)
# ('1904 Summer', 'South Africa', None, None, None)
# ('1906 Summer', 'Australia', None, None, 3)
# ('1906 Summer', 'Czech Republic', None, None, 3)
# ('1906 Summer', 'Egypt', None, None, None)
# ('1906 Summer', 'Netherlands', None, 1, 5)
# ('1906 Summer', 'Turkey', None, None, None)
# ('1908 Summer', 'Argentina', None, None, None)
# ('1908 Summer', 'Austria', None, None, 1)
# ('1908 Summer', 'Czech Republic', None, None, 6)
# ('1908 Summer', 'Denmark', None, 14, 3)
# ('1908 Summer', 'Greece', None, 3, 1)
# ('1908 Summer', 'Iceland', None, None, None)
# ('1908 Summer', 'Netherlands', None, None, 16)
# ('1908 Summer', 'Switzerland', None, None, None)
# ('1912 Summer', 'Austria', None, 9, 5)
# ('1912 Summer', 'Chile', None, None, None)
# ('1912 Summer', 'Czech Republic', None, None, None)
# ('1912 Summer', 'Iceland', None, None, None)
# ('1912 Summer', 'Japan', None, None, None)
# ('1912 Summer', 'Luxembourg', None, None, None)
# ('1912 Summer', 'NA', None, None, None)
# ('1912 Summer', 'Netherlands', None, None, 26)
# ('1912 Summer', 'Poland', None, None, None)
# ('1912 Summer', 'Portugal', None, None, None)
# ('1912 Summer', 'Russia', None, 5, 9)
# ('1912 Summer', 'Serbia', None, None, None)
# ('1912 Summer', 'Turkey', None, None, None)
# ('1920 Summer', 'Argentina', None, None, None)
# ('1920 Summer', 'Australia', None, 6, 1)
# ('1920 Summer', 'Chile', None, None, None)
# ('1920 Summer', 'Czech Republic', None, None, 10)
# ('1920 Summer', 'Egypt', None, None, None)
# ('1920 Summer', 'Greece', None, 5, None)
# ('1920 Summer', 'India', None, None, None)
# ('1920 Summer', 'Japan', None, 3, None)
# ('1920 Summer', 'Luxembourg', None, 1, None)
# ('1920 Summer', 'Monaco', None, None, None)
# ('1920 Summer', 'New Zealand', None, None, 1)
# ('1920 Summer', 'Portugal', None, None, None)
# ('1920 Summer', 'Serbia', None, None, None)
# ('1920 Summer', 'Spain', None, 23, None)
# ('1924 Summer', 'Austria', None, 3, 1)
# ('1924 Summer', 'Brazil', None, None, None)
# ('1924 Summer', 'Bulgaria', None, None, None)
# ('1924 Summer', 'Canada', None, 19, 1)
# ('1924 Summer', 'Chile', None, None, None)
# ('1924 Summer', 'Cuba', None, None, None)
# ('1924 Summer', 'Ecuador', None, None, None)
# ('1924 Summer', 'Egypt', None, None, None)
# ('1924 Summer', 'Haiti', None, None, 5)
# ('1924 Summer', 'India', None, None, None)
# ('1924 Summer', 'Ireland', None, 1, 1)
# ('1924 Summer', 'Japan', None, None, 1)
# ('1924 Summer', 'Latvia', None, None, None)
# ('1924 Summer', 'Lithuania', None, None, None)
# ('1924 Summer', 'Mexico', None, None, None)
# ('1924 Summer', 'Monaco', None, None, 1)
# ('1924 Summer', 'New Zealand', None, None, 1)
# ('1924 Summer', 'Philippines', None, None, None)
# ('1924 Summer', 'Poland', None, 4, 1)
# ('1924 Summer', 'Portugal', None, None, 4)
# ('1924 Summer', 'Romania', None, None, 16)
# ('1924 Summer', 'Russia', None, None, None)
# ('1924 Summer', 'Spain', None, None, None)
# ('1924 Summer', 'Turkey', None, None, None)
# ('1924 Winter', 'Belgium', None, None, 5)
# ('1924 Winter', 'Czech Republic', None, None, None)
# ('1924 Winter', 'France', None, None, 10)
# ('1924 Winter', 'Hungary', None, None, None)
# ('1924 Winter', 'Italy', None, None, None)
# ('1924 Winter', 'Latvia', None, None, None)
# ('1924 Winter', 'Poland', None, None, None)
# ('1924 Winter', 'Serbia', None, None, None)
# ('1928 Summer', 'Belgium', None, 1, 4)
# ('1928 Summer', 'Bulgaria', None, None, None)
# ('1928 Summer', 'Chile', None, 1, None)
# ('1928 Summer', 'Cuba', None, None, None)
# ('1928 Summer', 'Greece', None, None, None)
# ('1928 Summer', 'Haiti', None, 1, None)
# ('1928 Summer', 'Latvia', None, None, None)
# ('1928 Summer', 'Lithuania', None, None, None)
# ('1928 Summer', 'Malta', None, None, None)
# ('1928 Summer', 'Mexico', None, None, None)
# ('1928 Summer', 'Monaco', None, None, None)
# ('1928 Summer', 'Panama', None, None, None)
# ('1928 Summer', 'Philippines', None, None, 1)
# ('1928 Summer', 'Portugal', None, None, 6)
# ('1928 Summer', 'Romania', None, None, None)
# ('1928 Summer', 'Turkey', None, None, None)
# ('1928 Summer', 'Zimbabwe', None, None, None)
# ('1928 Winter', 'Argentina', None, None, None)
# ('1928 Winter', 'Austria', None, 4, 2)
# ('1928 Winter', 'Belgium', None, None, 1)
# ('1928 Winter', 'Czech Republic', None, None, 1)
# ('1928 Winter', 'Estonia', None, None, None)
# ('1928 Winter', 'Germany', None, None, 5)
# ('1928 Winter', 'Hungary', None, None, None)
# ('1928 Winter', 'Italy', None, None, None)
# ('1928 Winter', 'Japan', None, None, None)
# ('1928 Winter', 'Latvia', None, None, None)
# ('1928 Winter', 'Lithuania', None, None, None)
# ('1928 Winter', 'Luxembourg', None, None, None)
# ('1928 Winter', 'Mexico', None, None, None)
# ('1928 Winter', 'Netherlands', None, None, None)
# ('1928 Winter', 'Poland', None, None, None)
# ('1928 Winter', 'Romania', None, None, None)
# ('1928 Winter', 'Serbia', None, None, None)
# ('1928 Winter', 'Switzerland', None, None, 12)
# ('1928 Winter', 'UK', None, None, 1)
# ('1932 Summer', 'Belgium', None, None, 1)
# ('1932 Summer', 'Brazil', None, None, None)
# ('1932 Summer', 'Bulgaria', None, None, None)
# ('1932 Summer', 'China', None, None, None)
# ('1932 Summer', 'Colombia', None, None, None)
# ('1932 Summer', 'Cuba', None, None, None)
# ('1932 Summer', 'Denmark', None, 7, 4)
# ('1932 Summer', 'El Salvador', None, None, None)
# ('1932 Summer', 'Estonia', None, None, None)
# ('1932 Summer', 'Greece', None, None, None)
# ('1932 Summer', 'Guatemala', None, None, None)
# ('1932 Summer', 'Haiti', None, None, None)
# ('1932 Summer', 'Latvia', None, 1, None)
# ...
# ('2012 Summer', 'Bermuda', None, None, None)
# ('2012 Summer', 'Bhutan', None, None, None)
# ('2012 Summer', 'Boliva', None, None, None)
# ('2012 Summer', 'Bosnia and Herzegovina', None, None, None)
# ('2012 Summer', 'Botswana', None, 1, None)
# ('2012 Summer', 'Brunei', None, None, None)
# ('2012 Summer', 'Bulgaria', None, 1, 1)
# ('2012 Summer', 'Burkina Faso', None, None, None)
# ('2012 Summer', 'Burundi', None, None, None)
# ('2012 Summer', 'Cambodia', None, None, None)
# ('2012 Summer', 'Cameroon', None, None, None)
# ('2012 Summer', 'Cape Verde', None, None, None)
# ('2012 Summer', 'Cayman Islands', None, None, None)
# ('2012 Summer', 'Central African Republic', None, None, None)
# ('2012 Summer', 'Chad', None, None, None)
# ('2012 Summer', 'Chile', None, None, None)
# ('2012 Summer', 'Comoros', None, None, None)
# ('2012 Summer', 'Cook Islands', None, None, None)
# ('2012 Summer', 'Costa Rica', None, None, None)
# ('2012 Summer', 'Cyprus', None, 1, None)
# ('2012 Summer', 'Democratic Republic of the Congo', None, None, None)
# ('2012 Summer', 'Djibouti', None, None, None)
# ('2012 Summer', 'Dominica', None, None, None)
# ('2012 Summer', 'Ecuador', None, None, None)
# ('2012 Summer', 'Egypt', None, 2, None)
# ('2012 Summer', 'El Salvador', None, None, None)
# ('2012 Summer', 'Equatorial Guinea', None, None, None)
# ('2012 Summer', 'Eritrea', None, None, None)
# ('2012 Summer', 'Estonia', None, 1, 1)
# ('2012 Summer', 'Fiji', None, None, None)
# ('2012 Summer', 'Finland', None, 1, 4)
# ('2012 Summer', 'Gabon', None, 1, None)
# ('2012 Summer', 'Gambia', None, None, None)
# ('2012 Summer', 'Ghana', None, None, None)
# ('2012 Summer', 'Greece', None, None, 3)
# ('2012 Summer', 'Guam', None, None, None)
# ('2012 Summer', 'Guatemala', None, 1, None)
# ('2012 Summer', 'Guinea', None, None, None)
# ('2012 Summer', 'Guinea-Bissau', None, None, None)
# ('2012 Summer', 'Guyana', None, None, None)
# ('2012 Summer', 'Haiti', None, None, None)
# ('2012 Summer', 'Honduras', None, None, None)
# ('2012 Summer', 'Iceland', None, None, None)
# ('2012 Summer', 'India', None, 2, 4)
# ('2012 Summer', 'Individual Olympic Athletes', None, None, None)
# ('2012 Summer', 'Indonesia', None, 1, 1)
# ('2012 Summer', 'Iraq', None, None, None)
# ('2012 Summer', 'Israel', None, None, None)
# ('2012 Summer', 'Ivory Coast', None, None, None)
# ('2012 Summer', 'Jordan', None, None, None)
# ('2012 Summer', 'Kiribati', None, None, None)
# ('2012 Summer', 'Kuwait', None, None, 1)
# ('2012 Summer', 'Kyrgyzstan', None, None, None)
# ('2012 Summer', 'Laos', None, None, None)
# ('2012 Summer', 'Lebanon', None, None, None)
# ('2012 Summer', 'Lesotho', None, None, None)
# ('2012 Summer', 'Liberia', None, None, None)
# ('2012 Summer', 'Libya', None, None, None)
# ('2012 Summer', 'Liechtenstein', None, None, None)
# ('2012 Summer', 'Luxembourg', None, None, None)
# ('2012 Summer', 'Macedonia', None, None, None)
# ('2012 Summer', 'Madagascar', None, None, None)
# ('2012 Summer', 'Malawi', None, None, None)
# ('2012 Summer', 'Malaysia', None, 1, 1)
# ('2012 Summer', 'Maldives', None, None, None)
# ('2012 Summer', 'Mali', None, None, None)
# ('2012 Summer', 'Malta', None, None, None)
# ('2012 Summer', 'Marshall Islands', None, None, None)
# ('2012 Summer', 'Mauritania', None, None, None)
# ('2012 Summer', 'Mauritius', None, None, None)
# ('2012 Summer', 'Micronesia', None, None, None)
# ('2012 Summer', 'Moldova', None, None, 2)
# ('2012 Summer', 'Monaco', None, None, None)
# ('2012 Summer', 'Mongolia', None, 2, 3)
# ('2012 Summer', 'Montenegro', None, 14, None)
# ('2012 Summer', 'Morocco', None, None, 1)
# ('2012 Summer', 'Mozambique', None, None, None)
# ('2012 Summer', 'Myanmar', None, None, None)
# ('2012 Summer', 'NA', None, None, None)
# ('2012 Summer', 'Namibia', None, None, None)
# ('2012 Summer', 'Nauru', None, None, None)
# ('2012 Summer', 'Nepal', None, None, None)
# ('2012 Summer', 'Nicaragua', None, None, None)
# ('2012 Summer', 'Niger', None, None, None)
# ('2012 Summer', 'Nigeria', None, None, None)
# ('2012 Summer', 'Oman', None, None, None)
# ('2012 Summer', 'Pakistan', None, None, None)
# ('2012 Summer', 'Palau', None, None, None)
# ('2012 Summer', 'Palestine', None, None, None)
# ('2012 Summer', 'Panama', None, None, None)
# ('2012 Summer', 'Papua New Guinea', None, None, None)
# ('2012 Summer', 'Paraguay', None, None, None)
# ('2012 Summer', 'Peru', None, None, None)
# ('2012 Summer', 'Philippines', None, None, None)
# ('2012 Summer', 'Portugal', None, 2, None)
# ('2012 Summer', 'Puerto Rico', None, 1, 1)
# ('2012 Summer', 'Qatar', None, None, 2)
# ('2012 Summer', 'Republic of Congo', None, None, None)
# ('2012 Summer', 'Rwanda', None, None, None)
# ('2012 Summer', 'Saint Kitts', None, None, None)
# ('2012 Summer', 'Saint Lucia', None, None, None)
# ('2012 Summer', 'Saint Vincent', None, None, None)
# ('2012 Summer', 'Samoa', None, None, None)
# ('2012 Summer', 'San Marino', None, None, None)
# ('2012 Summer', 'Sao Tome and Principe', None, None, None)
# ('2012 Summer', 'Saudi Arabia', None, None, 4)
# ('2012 Summer', 'Senegal', None, None, None)
# ('2012 Summer', 'Seychelles', None, None, None)
# ('2012 Summer', 'Sierra Leone', None, None, None)
# ('2012 Summer', 'Slovakia', None, 1, 4)
# ('2012 Summer', 'Solomon Islands', None, None, None)
# ('2012 Summer', 'Somalia', None, None, None)
# ('2012 Summer', 'Sri Lanka', None, None, None)
# ('2012 Summer', 'Sudan', None, None, None)
# ('2012 Summer', 'Suriname', None, None, None)
# ('2012 Summer', 'Swaziland', None, None, None)
# ('2012 Summer', 'Syria', None, None, None)
# ('2012 Summer', 'Taiwan', None, 1, 1)
# ('2012 Summer', 'Tajikistan', None, None, 1)
# ('2012 Summer', 'Tanzania', None, None, None)
# ('2012 Summer', 'Thailand', None, 2, 1)
# ('2012 Summer', 'Timor-Leste', None, None, None)
# ('2012 Summer', 'Togo', None, None, None)
# ('2012 Summer', 'Tonga', None, None, None)
# ('2012 Summer', 'Turkmenistan', None, None, None)
# ('2012 Summer', 'United Arab Emirates', None, None, None)
# ('2012 Summer', 'Uruguay', None, None, None)
# ('2012 Summer', 'Vanuatu', None, None, None)
# ('2012 Summer', 'Vietnam', None, None, None)
# ('2012 Summer', 'Virgin Islands, British', None, None, None)
# ('2012 Summer', 'Virgin Islands, US', None, None, None)
# ('2012 Summer', 'Yemen', None, None, None)
# ('2012 Summer', 'Zambia', None, None, None)
# ('2012 Summer', 'Zimbabwe', None, None, None)
# ('2014 Winter', 'Albania', None, None, None)
# ('2014 Winter', 'Andorra', None, None, None)
# ('2014 Winter', 'Argentina', None, None, None)
# ('2014 Winter', 'Armenia', None, None, None)
# ('2014 Winter', 'Australia', None, 2, 1)
# ('2014 Winter', 'Azerbaijan', None, None, None)
# ('2014 Winter', 'Belgium', None, None, None)
# ('2014 Winter', 'Bermuda', None, None, None)
# ('2014 Winter', 'Bosnia and Herzegovina', None, None, None)
# ('2014 Winter', 'Brazil', None, None, None)
# ('2014 Winter', 'Bulgaria', None, None, None)
# ('2014 Winter', 'Cayman Islands', None, None, None)
# ('2014 Winter', 'Chile', None, None, None)
# ('2014 Winter', 'Croatia', None, 1, None)
# ('2014 Winter', 'Cyprus', None, None, None)
# ('2014 Winter', 'Denmark', None, None, None)
# ('2014 Winter', 'Dominica', None, None, None)
# ('2014 Winter', 'Estonia', None, None, None)
# ('2014 Winter', 'Georgia', None, None, None)
# ('2014 Winter', 'Greece', None, None, None)
# ('2014 Winter', 'Hungary', None, None, None)
# ('2014 Winter', 'Iceland', None, None, None)
# ('2014 Winter', 'India', None, None, None)
# ('2014 Winter', 'Individual Olympic Athletes', None, None, None)
# ('2014 Winter', 'Iran', None, None, None)
# ('2014 Winter', 'Ireland', None, None, None)
# ('2014 Winter', 'Israel', None, None, None)
# ('2014 Winter', 'Italy', None, 2, 12)
# ('2014 Winter', 'Jamaica', None, None, None)
# ('2014 Winter', 'Kazakhstan', None, None, 1)
# ('2014 Winter', 'Kyrgyzstan', None, None, None)
# ('2014 Winter', 'Latvia', None, 5, 6)
# ('2014 Winter', 'Lebanon', None, None, None)
# ('2014 Winter', 'Liechtenstein', None, None, None)
# ('2014 Winter', 'Lithuania', None, None, None)
# ('2014 Winter', 'Luxembourg', None, None, None)
# ('2014 Winter', 'Macedonia', None, None, None)
# ('2014 Winter', 'Malta', None, None, None)
# ('2014 Winter', 'Mexico', None, None, None)
# ('2014 Winter', 'Moldova', None, None, None)
# ('2014 Winter', 'Monaco', None, None, None)
# ('2014 Winter', 'Mongolia', None, None, None)
# ('2014 Winter', 'Montenegro', None, None, None)
# ('2014 Winter', 'Morocco', None, None, None)
# ('2014 Winter', 'Nepal', None, None, None)
# ('2014 Winter', 'New Zealand', None, None, None)
# ('2014 Winter', 'Pakistan', None, None, None)
# ('2014 Winter', 'Paraguay', None, None, None)
# ('2014 Winter', 'Peru', None, None, None)
# ('2014 Winter', 'Philippines', None, None, None)
# ('2014 Winter', 'Portugal', None, None, None)
# ('2014 Winter', 'Romania', None, None, None)
# ('2014 Winter', 'San Marino', None, None, None)
# ('2014 Winter', 'Serbia', None, None, None)
# ('2014 Winter', 'Spain', None, None, None)
# ('2014 Winter', 'Taiwan', None, None, None)
# ('2014 Winter', 'Tajikistan', None, None, None)
# ('2014 Winter', 'Thailand', None, None, None)
# ('2014 Winter', 'Timor-Leste', None, None, None)
# ('2014 Winter', 'Togo', None, None, None)
# ('2014 Winter', 'Tonga', None, None, None)
# ('2014 Winter', 'Turkey', None, None, None)
# ('2014 Winter', 'Uzbekistan', None, None, None)
# ('2014 Winter', 'Venezuela', None, None, None)
# ('2014 Winter', 'Virgin Islands, British', None, None, None)
# ('2014 Winter', 'Virgin Islands, US', None, None, None)
# ('2014 Winter', 'Zimbabwe', None, None, None)
# ('2016 Summer', 'Afghanistan', None, None, None)
# ('2016 Summer', 'Albania', None, None, None)
# ('2016 Summer', 'Algeria', None, 2, None)
# ('2016 Summer', 'American Samoa', None, None, None)
# ('2016 Summer', 'Andorra', None, None, None)
# ('2016 Summer', 'Angola', None, None, None)
# ('2016 Summer', 'Antigua', None, None, None)
# ('2016 Summer', 'Aruba', None, None, None)
# ('2016 Summer', 'Austria', None, None, 2)
# ('2016 Summer', 'Bangladesh', None, None, None)
# ('2016 Summer', 'Barbados', None, None, None)
# ('2016 Summer', 'Belize', None, None, None)
# ('2016 Summer', 'Benin', None, None, None)
# ('2016 Summer', 'Bermuda', None, None, None)
# ('2016 Summer', 'Bhutan', None, None, None)
# ('2016 Summer', 'Boliva', None, None, None)
# ('2016 Summer', 'Bosnia and Herzegovina', None, None, None)
# ('2016 Summer', 'Botswana', None, None, None)
# ('2016 Summer', 'Brunei', None, None, None)
# ('2016 Summer', 'Bulgaria', None, 1, 6)
# ('2016 Summer', 'Burkina Faso', None, None, None)
# ('2016 Summer', 'Burundi', None, 1, None)
# ('2016 Summer', 'Cambodia', None, None, None)
# ('2016 Summer', 'Cameroon', None, None, None)
# ('2016 Summer', 'Cape Verde', None, None, None)
# ('2016 Summer', 'Cayman Islands', None, None, None)
# ('2016 Summer', 'Central African Republic', None, None, None)
# ('2016 Summer', 'Chad', None, None, None)
# ('2016 Summer', 'Chile', None, None, None)
# ('2016 Summer', 'Comoros', None, None, None)
# ('2016 Summer', 'Cook Islands', None, None, None)
# ('2016 Summer', 'Costa Rica', None, None, None)
# ('2016 Summer', 'Cyprus', None, None, None)
# ('2016 Summer', 'Democratic Republic of the Congo', None, None, None)
# ('2016 Summer', 'Djibouti', None, None, None)
# ('2016 Summer', 'Dominica', None, None, None)
# ('2016 Summer', 'Dominican Republic', None, None, 1)
# ('2016 Summer', 'Ecuador', None, None, None)
# ('2016 Summer', 'Egypt', None, None, 3)
# ('2016 Summer', 'El Salvador', None, None, None)
# ('2016 Summer', 'Equatorial Guinea', None, None, None)
# ('2016 Summer', 'Eritrea', None, None, None)
# ('2016 Summer', 'Estonia', None, None, 4)
# ('2016 Summer', 'Finland', None, None, 1)
# ('2016 Summer', 'Gabon', None, None, None)
# ('2016 Summer', 'Gambia', None, None, None)
# ('2016 Summer', 'Ghana', None, None, None)
# ('2016 Summer', 'Grenada', None, 1, None)
# ('2016 Summer', 'Guam', None, None, None)
# ('2016 Summer', 'Guatemala', None, None, None)
# ('2016 Summer', 'Guinea', None, None, None)
# ('2016 Summer', 'Guinea-Bissau', None, None, None)
# ('2016 Summer', 'Guyana', None, None, None)
# ('2016 Summer', 'Haiti', None, None, None)
# ('2016 Summer', 'Honduras', None, None, None)
# ('2016 Summer', 'Iceland', None, None, None)
# ('2016 Summer', 'India', None, 1, 1)
# ('2016 Summer', 'Iraq', None, None, None)
# ('2016 Summer', 'Ireland', None, 3, None)
# ('2016 Summer', 'Israel', None, None, 2)
# ('2016 Summer', 'Kiribati', None, None, None)
# ('2016 Summer', 'Kyrgyzstan', None, None, None)
# ('2016 Summer', 'Laos', None, None, None)
# ('2016 Summer', 'Latvia', None, None, None)
# ('2016 Summer', 'Lebanon', None, None, None)
# ('2016 Summer', 'Lesotho', None, None, None)
# ('2016 Summer', 'Liberia', None, None, None)
# ('2016 Summer', 'Libya', None, None, None)
# ('2016 Summer', 'Liechtenstein', None, None, None)
# ('2016 Summer', 'Lithuania', None, 2, 5)
# ('2016 Summer', 'Luxembourg', None, None, None)
# ('2016 Summer', 'Macedonia', None, None, None)
# ('2016 Summer', 'Madagascar', None, None, None)
# ('2016 Summer', 'Malawi', None, None, None)
# ('2016 Summer', 'Malaysia', None, 7, 1)
# ('2016 Summer', 'Maldives', None, None, None)
# ('2016 Summer', 'Mali', None, None, None)
# ('2016 Summer', 'Malta', None, None, None)
# ('2016 Summer', 'Marshall Islands', None, None, None)
# ('2016 Summer', 'Mauritania', None, None, None)
# ('2016 Summer', 'Mauritius', None, None, None)
# ('2016 Summer', 'Mexico', None, 3, 2)
# ('2016 Summer', 'Micronesia', None, None, None)
# ('2016 Summer', 'Moldova', None, None, None)
# ('2016 Summer', 'Monaco', None, None, None)
# ('2016 Summer', 'Mongolia', None, 1, 1)
# ('2016 Summer', 'Montenegro', None, None, None)
# ('2016 Summer', 'Morocco', None, None, 1)
# ('2016 Summer', 'Mozambique', None, None, None)
# ('2016 Summer', 'Myanmar', None, None, None)
# ('2016 Summer', 'NA', None, None, None)
# ('2016 Summer', 'Namibia', None, None, None)
# ('2016 Summer', 'Nauru', None, None, None)
# ('2016 Summer', 'Nepal', None, None, None)
# ('2016 Summer', 'Nicaragua', None, None, None)
# ('2016 Summer', 'Niger', None, 1, None)
# ('2016 Summer', 'Nigeria', None, None, 18)
# ('2016 Summer', 'Norway', None, None, 19)
# ('2016 Summer', 'Oman', None, None, None)
# ('2016 Summer', 'Pakistan', None, None, None)
# ('2016 Summer', 'Palau', None, None, None)
# ('2016 Summer', 'Palestine', None, None, None)
# ('2016 Summer', 'Panama', None, None, None)
# ('2016 Summer', 'Papua New Guinea', None, None, None)
# ('2016 Summer', 'Paraguay', None, None, None)
# ('2016 Summer', 'Peru', None, None, None)
# ('2016 Summer', 'Philippines', None, 1, None)
# ('2016 Summer', 'Portugal', None, None, 1)
# ('2016 Summer', 'Qatar', None, 1, None)
# ('2016 Summer', 'Republic of Congo', None, None, None)
# ('2016 Summer', 'Rwanda', None, None, None)
# ('2016 Summer', 'Saint Kitts', None, None, None)
# ('2016 Summer', 'Saint Lucia', None, None, None)
# ('2016 Summer', 'Saint Vincent', None, None, None)
# ('2016 Summer', 'Samoa', None, None, None)
# ('2016 Summer', 'San Marino', None, None, None)
# ('2016 Summer', 'Sao Tome and Principe', None, None, None)
# ('2016 Summer', 'Saudi Arabia', None, None, None)
# ('2016 Summer', 'Senegal', None, None, None)
# ('2016 Summer', 'Seychelles', None, None, None)
# ('2016 Summer', 'Sierra Leone', None, None, None)
# ('2016 Summer', 'Solomon Islands', None, None, None)
# ('2016 Summer', 'Somalia', None, None, None)
# ('2016 Summer', 'South Sudan', None, None, None)
# ('2016 Summer', 'Sri Lanka', None, None, None)
# ('2016 Summer', 'Sudan', None, None, None)
# ('2016 Summer', 'Suriname', None, None, None)
# ('2016 Summer', 'Swaziland', None, None, None)
# ('2016 Summer', 'Syria', None, None, None)
# ('2016 Summer', 'Tanzania', None, None, None)
# ('2016 Summer', 'Timor-Leste', None, None, None)
# ('2016 Summer', 'Togo', None, None, None)
# ('2016 Summer', 'Tonga', None, None, None)
# ('2016 Summer', 'Trinidad', None, None, 1)
# ('2016 Summer', 'Tunisia', None, None, 3)
# ('2016 Summer', 'Turkmenistan', None, None, None)
# ('2016 Summer', 'Uganda', None, None, None)
# ('2016 Summer', 'United Arab Emirates', None, None, 1)
# ('2016 Summer', 'Uruguay', None, None, None)
# ('2016 Summer', 'Vanuatu', None, None, None)
# ('2016 Summer', 'Venezuela', None, 1, 2)
# ('2016 Summer', 'Virgin Islands, British', None, None, None)
# ('2016 Summer', 'Virgin Islands, US', None, None, None)
# ('2016 Summer', 'Yemen', None, None, None)
# ('2016 Summer', 'Zambia', None, None, None)
# ('2016 Summer', 'Zimbabwe', None, None, None)

# %%
# 17. Identify which country won the most gold, most silver and most bronze medals in each olympic games.
with sqlite3.connect('olympics.db') as conn:
    cursor = conn.cursor()
    query = ''' 
            
            '''
    # TODO
    cursor.execute(query)
    for entry in cursor.fetchall():
        print(entry)

# %%
# 18. Identify which country won the most gold, most silver, most bronze medals and the most medals in each olympic games.
with sqlite3.connect('olympics.db') as conn:
    cursor = conn.cursor()
    query = ''' 
            
            '''
    # TODO
    cursor.execute(query)
    for entry in cursor.fetchall():
        print(entry)

# %%
# 19. Which countries have never won gold medal but have won silver/bronze medals?
with sqlite3.connect('olympics.db') as conn:
    cursor = conn.cursor()
    query = ''' 
                WITH T1 AS (
                SELECT region,
                CASE Medal
                    WHEN 'Gold' THEN 1
                    ELSE 0
                END AS Gold,
                CASE Medal
                    WHEN 'Silver' THEN 1
                    ELSE 0
                END AS Silver,
                CASE Medal
                    WHEN 'Bronze' THEN 1
                    ELSE 0
                END AS Bronze
                FROM athlete_events
                JOIN noc_regions on noc_regions.NOC = athlete_events.NOC
                )

                SELECT region, SUM(Gold) AS Gold_num, SUM(Silver) AS Silver_num, SUM(Bronze) AS Bronze_num
                FROM T1
                GROUP BY region
                HAVING Gold_num = 0 AND (Silver_num > 0 OR Bronze_num > 0)
            '''

    cursor.execute(query)
    for entry in cursor.fetchall():
        print(entry)
# Out:
# ('Afghanistan', 0, 0, 2)
# ('Barbados', 0, 0, 1)
# ('Bermuda', 0, 0, 1)
# ('Botswana', 0, 1, 0)
# ('Curacao', 0, 1, 0)
# ('Cyprus', 0, 1, 0)
# ('Djibouti', 0, 0, 1)
# ('Eritrea', 0, 0, 1)
# ('Gabon', 0, 1, 0)
# ('Ghana', 0, 1, 22)
# ('Guatemala', 0, 1, 0)
# ('Guyana', 0, 0, 1)
# ('Iceland', 0, 15, 2)
# ('Iraq', 0, 0, 1)
# ('Kuwait', 0, 0, 2)
# ('Kyrgyzstan', 0, 1, 2)
# ('Lebanon', 0, 2, 2)
# ('Macedonia', 0, 0, 1)
# ('Malaysia', 0, 11, 5)
# ('Mauritius', 0, 0, 1)
# ('Moldova', 0, 3, 5)
# ('Monaco', 0, 0, 1)
# ('Montenegro', 0, 14, 0)
# ('Namibia', 0, 4, 0)
# ('Niger', 0, 1, 1)
# ('Paraguay', 0, 17, 0)
# ('Philippines', 0, 3, 7)
# ('Qatar', 0, 1, 4)
# ('Saudi Arabia', 0, 1, 5)
# ('Senegal', 0, 1, 0)
# ('Sri Lanka', 0, 2, 0)
# ('Sudan', 0, 1, 0)
# ('Tanzania', 0, 2, 0)
# ('Togo', 0, 0, 1)
# ('Tonga', 0, 1, 0)
# ('Virgin Islands, US', 0, 1, 0)
# ('Zambia', 0, 1, 1)

# %%
# 20. In which Sport/event, India has won highest medals.
with sqlite3.connect('olympics.db') as conn:
    cursor = conn.cursor()
    query = ''' 
                SELECT region, Sport, COUNT(Medal) as count_medals
                FROM (
                    SELECT n.region, a.Games, a.Sport, a.Medal
                    FROM athlete_events a
                    JOIN noc_regions n ON n.NOC = a.NOC
                    WHERE a.Medal != 'NA' AND  n.region = 'India'
                )
                GROUP BY Sport
                ORDER BY count_medals DESC
            '''

    cursor.execute(query)
    for entry in cursor.fetchall():
        print(entry)
# Out:
# ('India', 'Hockey', 173)
# ('India', 'Alpinism', 7)
# ('India', 'Wrestling', 5)
# ('India', 'Shooting', 4)
# ('India', 'Boxing', 2)
# ('India', 'Badminton', 2)
# ('India', 'Athletics', 2)
# ('India', 'Weightlifting', 1)
# ('India', 'Tennis', 1)

# %%
# 21. Break down all olympic games where india won medal for Hockey and how many medals in each olympic games.

with sqlite3.connect('olympics.db') as conn:
    cursor = conn.cursor()
    query = ''' 
                SELECT region, Sport, Games, COUNT(Medal) AS count_medals
                FROM (
                    SELECT n.region, a.Games, a.Sport, a.Medal
                    FROM athlete_events a
                    JOIN noc_regions n ON n.NOC = a.NOC
                    WHERE a.Medal != 'NA'AND  n.region = 'India' AND a.Sport = 'Hockey' 
                )
                GROUP BY Games
                ORDER BY count_medals DESC
            '''

    cursor.execute(query)
    for entry in cursor.fetchall():
        print(entry)
# Out:
# ('India', 'Hockey', '1948 Summer', 20)
# ('India', 'Hockey', '1936 Summer', 19)
# ('India', 'Hockey', '1956 Summer', 17)
# ('India', 'Hockey', '1980 Summer', 16)
# ('India', 'Hockey', '1968 Summer', 16)
# ('India', 'Hockey', '1964 Summer', 15)
# ('India', 'Hockey', '1932 Summer', 15)
# ('India', 'Hockey', '1972 Summer', 14)
# ('India', 'Hockey', '1952 Summer', 14)
# ('India', 'Hockey', '1928 Summer', 14)
# ('India', 'Hockey', '1960 Summer', 13)
